# %%
# !pip install gymnasium
# !pip install stable-baselines3[extra]
# !pip install tensorboard
# %load_ext tensorboard
# !pip install torch --upgrade --force-reinstall
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: stable-baselines3[extra] in /usr/local/lib/python3.11/dist-packages (2.4.1)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: numpy<2.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (2.5.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (3.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (3.10.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (4.10.0.84)
# Requirement already satisfied: pygame in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (2.17.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (13.9.4)
# Requirement already satisfied: ale-py>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (0.10.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (11.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3[extra]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.69.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (4.25.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (75.1.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3[extra]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3[extra]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3[extra]) (2024.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->stable-baselines3[extra]) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (2.17.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (1.69.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (3.7)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorboard) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (4.25.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (75.1.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Collecting torch
#   Using cached torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting filelock (from torch)
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.8.0 (from torch)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting networkx (from torch)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Using cached jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch)
#   Using cached fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Using cached nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch)
#   Using cached nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch)
#   Using cached triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting sympy==1.13.1 (from torch)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Using cached MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Using cached torch-2.5.1-cp311-cp311-manylinux1_x86_64.whl (906.5 MB)
# Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
# Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
# Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
# Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
# Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
# Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
# Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
# Using cached nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
# Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Using cached nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached triton-3.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Using cached fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Using cached jinja2-3.1.5-py3-none-any.whl (134 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, typing-extensions, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, MarkupSafe, fsspec, filelock, triton, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, torch
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.4.127
#     Uninstalling nvidia-nvjitlink-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.4.127
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.5.147
#     Uninstalling nvidia-curand-cu12-10.3.5.147:
#       Successfully uninstalled nvidia-curand-cu12-10.3.5.147
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.1.3
#     Uninstalling nvidia-cufft-cu12-11.2.1.3:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.1.3
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.4.127
#     Uninstalling nvidia-cuda-runtime-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.4.127
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.4.127
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.4.127
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.4.127
#     Uninstalling nvidia-cuda-cupti-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.4.127
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.4.5.8
#     Uninstalling nvidia-cublas-cu12-12.4.5.8:
#       Successfully uninstalled nvidia-cublas-cu12-12.4.5.8
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.4.2
#     Uninstalling networkx-3.4.2:
#       Successfully uninstalled networkx-3.4.2
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.12.0
#     Uninstalling fsspec-2024.12.0:
#       Successfully uninstalled fsspec-2024.12.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.16.1
#     Uninstalling filelock-3.16.1:
#       Successfully uninstalled filelock-3.16.1
#   Attempting uninstall: triton
#     Found existing installation: triton 3.1.0
#     Uninstalling triton-3.1.0:
#       Successfully uninstalled triton-3.1.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.3.1.170
#     Uninstalling nvidia-cusparse-cu12-12.3.1.170:
#       Successfully uninstalled nvidia-cusparse-cu12-12.3.1.170
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.1.0.70
#     Uninstalling nvidia-cudnn-cu12-9.1.0.70:
#       Successfully uninstalled nvidia-cudnn-cu12-9.1.0.70
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.5
#     Uninstalling Jinja2-3.1.5:
#       Successfully uninstalled Jinja2-3.1.5
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.1.9
#     Uninstalling nvidia-cusolver-cu12-11.6.1.9:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.1.9
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1
#     Uninstalling torch-2.5.1:
#       Successfully uninstalled torch-2.5.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed MarkupSafe-3.0.2 filelock-3.16.1 fsspec-2024.12.0 jinja2-3.1.5 mpmath-1.3.0 networkx-3.4.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 sympy-1.13.1 torch-2.5.1 triton-3.1.0 typing-extensions-4.12.2

# %% [markdown]
# # **DQN agent with tweaked binary rewards for storage volume constraints with smaller time steps (threshold) each episode**

# %%
# Import necessary libraries
import os
import numpy as np
import pandas as pd
import torch as th
import gymnasium
from gymnasium import Env
from gymnasium.spaces import Discrete, Box
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# Define storage and release limits
min_storage_af = 500000
max_storage_af = 1600000
initial_storage_af = 500000
target_storage_af = (min_storage_af + max_storage_af) / 2
release_cfs = [500, 1000, 1500, 2000, 2500, 3000]  # More discrete release values
release_af = [r * 1.98211 for r in release_cfs]  # Convert cfs to acre-feet

# Define the custom Reservoir environment
class ReservoirEnv(Env):
    def __init__(self, data, scaler, episode_length):
        super(ReservoirEnv, self).__init__()
        self.data = data
        self.scaler = scaler
        self.episode_length = episode_length
        self.current_step = 0
        self.storage_history = []
        self.predicted_release_history = []
        self.reward_history = []
        self.q_values = []

        # Unscaled data for actual values
        unscaled_data = self.scaler.inverse_transform(self.data)
        self.actual_storage_history = unscaled_data[:, 0].tolist()
        self.actual_release_history = unscaled_data[:, 3].tolist()
        self.evaporation_history = unscaled_data[:, 1].tolist()
        self.inflow_history = unscaled_data[:, 2].tolist()

        # Define action space and observation space
        self.action_space = Discrete(len(release_af))  # Actions: release values in af
        self.observation_space = Box(low=0, high=1, shape=(3,), dtype=np.float32)

    def reset(self, seed=None):
        self.current_step = np.random.randint(0, len(self.data) - self.episode_length)
        self.episode_step_count = 0
        self.storage_history.clear()
        self.predicted_release_history.clear()
        self.reward_history.clear()
        self.q_values.clear()

        # Set the storage to the value corresponding to the start of the episode
        self.current_storage = self.scaler.inverse_transform(
            self.data[self.current_step:self.current_step + 1, :]
        )[0, 0]
        self.storage_history.append(self.current_storage)
        return self._get_observation(), {}

    def _get_observation(self):
        return self.data[self.current_step, :3]

    def step(self, action):
        release_af_value = release_af[action]  # Map action index to release value
        inflow_af = self.scaler.inverse_transform(
            self.data[self.current_step:self.current_step + 1, :]
        )[0, 2]
        evaporation_af = self.scaler.inverse_transform(
            self.data[self.current_step:self.current_step + 1, :]
        )[0, 1]

        # Update storage with inflow, evaporation, and release
        self.current_storage += inflow_af - evaporation_af - release_af_value
        self.predicted_release_history.append(release_af_value)
        self.storage_history.append(self.current_storage)

        # Reward calculation
        if min_storage_af <= self.current_storage <= max_storage_af:
            reward = 1 - (abs(self.current_storage - target_storage_af) / target_storage_af)
        else:
            reward = -1

        self.reward_history.append(reward)
        self.current_step += 1
        self.episode_step_count += 1
        done = self.current_step >= len(self.data) or (self.episode_step_count % self.episode_length == 0)
        observation = self._get_observation() if not done else np.zeros(3)
        return observation, reward, done, False, {}

    def render(self, mode='human', close=False):
        pass


# Load and preprocess data
data = pd.read_csv('/content/Clipped_NAVAJORESERVOIR08-18-2024T16.48.23.csv')
storage = data['Storage (af)'].values
evaporation = data['Evaporation (af)'].values
inflow_cfs = data['Inflow** (cfs)'].values
release_cfs = data['Total Release (cfs)'].values
dataset = np.column_stack((storage, evaporation, inflow_cfs * 1.98211, release_cfs * 1.98211))
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(dataset)

# Set up environment
episode_length = 240
env = ReservoirEnv(scaled_data, scaler, episode_length=episode_length)

# Initialize and train DQN model
model = DQN(
    "MlpPolicy",
    env,
    verbose=1,
    learning_rate=1e-3,
    batch_size=32,
    train_freq=4,
    buffer_size=50000,
    exploration_fraction=0.3,
    exploration_final_eps=0.01,
    target_update_interval=1000,
)

# Train the model
n_episodes = 10000
total_timesteps = n_episodes * episode_length
model.learn(total_timesteps=total_timesteps)

# Save the model
model.save("dqn_reservoir_agent")

# Load the trained DQN agent
model = DQN.load("dqn_reservoir_agent")

# Reset the environment and initialize analysis lists
env = ReservoirEnv(scaled_data, scaler, episode_length=episode_length)
obs, _ = env.reset()

predicted_releases = []
actual_releases = []
predicted_storage = []
actual_storage = []
rewards = []
q_values = []

# Simulate the entire dataset
env.current_step = 0  # Start from the beginning of the dataset
done = False

while env.current_step < len(env.data):
    action, _ = model.predict(obs, deterministic=True)  # Get action from DQN agent
    obs, reward, done, _, _ = env.step(action)  # Step through the environment

    # Capture data for analysis
    predicted_releases.append(env.predicted_release_history[-1])
    actual_releases.append(env.actual_release_history[env.current_step - 1])
    predicted_storage.append(env.storage_history[-1])
    actual_storage.append(env.actual_storage_history[env.current_step - 1])
    rewards.append(reward)

    # Compute Q-values for the current observation
    q_value = model.q_net(th.tensor(obs, dtype=th.float32).unsqueeze(0)).detach().numpy().max()
    q_values.append(q_value)

    # Stop if the end of the dataset is reached
    if env.current_step >= len(env.data) - 1:
        break

# Save analysis results to CSV
results_df = pd.DataFrame({
    "Time Step": range(len(predicted_releases)),
    "Predicted Releases (af)": predicted_releases,
    "Actual Releases (af)": actual_releases,
    "Predicted Storage (af)": predicted_storage,
    "Actual Storage (af)": actual_storage,
    "Rewards": rewards,
    "Q Values": q_values,
})
results_df.to_csv("dqn_analysis_results.csv", index=False)
print("Analysis results saved to 'dqn_analysis_results.csv'.")

# Plot results
plt.figure(figsize=(12, 6))
plt.plot(predicted_releases, label="Predicted Releases", color="blue")
plt.plot(actual_releases, label="Actual Releases", linestyle="--", color="orange")
plt.xlabel("Time Step")
plt.ylabel("Releases (af)")
plt.legend()
plt.title("Predicted vs Actual Releases")
plt.grid()
plt.savefig("predicted_vs_actual_releases.png")
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(predicted_storage, label="Predicted Storage", color="green")
plt.plot(actual_storage, label="Actual Storage", linestyle="--", color="red")
plt.xlabel("Time Step")
plt.ylabel("Storage (af)")
plt.legend()
plt.title("Predicted vs Actual Storage")
plt.grid()
plt.savefig("predicted_vs_actual_storage.png")
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(rewards, label="Rewards", color="purple")
plt.xlabel("Time Step")
plt.ylabel("Reward")
plt.title("Rewards Over Time")
plt.grid()
plt.savefig("rewards_over_time.png")
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(q_values, label="Q Values", color="cyan")
plt.xlabel("Time Step")
plt.ylabel("Q Value")
plt.title("Q Values Over Time")
plt.grid()
plt.savefig("q_values_over_time.png")
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# |    learning_rate    | 0.001    |
# |    loss             | 0.719    |
# |    n_updates        | 520054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8672     |
# |    fps              | 658      |
# |    time_elapsed     | 3162     |
# |    total_timesteps  | 2081280  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.859    |
# |    n_updates        | 520294   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8676     |
# |    fps              | 658      |
# |    time_elapsed     | 3163     |
# |    total_timesteps  | 2082240  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.13     |
# |    n_updates        | 520534   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8680     |
# |    fps              | 658      |
# |    time_elapsed     | 3165     |
# |    total_timesteps  | 2083200  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.445    |
# |    n_updates        | 520774   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8684     |
# |    fps              | 658      |
# |    time_elapsed     | 3167     |
# |    total_timesteps  | 2084160  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.15     |
# |    n_updates        | 521014   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8688     |
# |    fps              | 657      |
# |    time_elapsed     | 3169     |
# |    total_timesteps  | 2085120  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.436    |
# |    n_updates        | 521254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8692     |
# |    fps              | 657      |
# |    time_elapsed     | 3170     |
# |    total_timesteps  | 2086080  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.475    |
# |    n_updates        | 521494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8696     |
# |    fps              | 657      |
# |    time_elapsed     | 3171     |
# |    total_timesteps  | 2087040  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.951    |
# |    n_updates        | 521734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8700     |
# |    fps              | 657      |
# |    time_elapsed     | 3173     |
# |    total_timesteps  | 2088000  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.814    |
# |    n_updates        | 521974   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8704     |
# |    fps              | 657      |
# |    time_elapsed     | 3174     |
# |    total_timesteps  | 2088960  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.516    |
# |    n_updates        | 522214   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8708     |
# |    fps              | 658      |
# |    time_elapsed     | 3176     |
# |    total_timesteps  | 2089920  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.718    |
# |    n_updates        | 522454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8712     |
# |    fps              | 658      |
# |    time_elapsed     | 3177     |
# |    total_timesteps  | 2090880  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.944    |
# |    n_updates        | 522694   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8716     |
# |    fps              | 658      |
# |    time_elapsed     | 3178     |
# |    total_timesteps  | 2091840  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.288    |
# |    n_updates        | 522934   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8720     |
# |    fps              | 657      |
# |    time_elapsed     | 3180     |
# |    total_timesteps  | 2092800  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.261    |
# |    n_updates        | 523174   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8724     |
# |    fps              | 657      |
# |    time_elapsed     | 3182     |
# |    total_timesteps  | 2093760  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.567    |
# |    n_updates        | 523414   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8728     |
# |    fps              | 657      |
# |    time_elapsed     | 3183     |
# |    total_timesteps  | 2094720  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.844    |
# |    n_updates        | 523654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8732     |
# |    fps              | 657      |
# |    time_elapsed     | 3185     |
# |    total_timesteps  | 2095680  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.426    |
# |    n_updates        | 523894   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8736     |
# |    fps              | 657      |
# |    time_elapsed     | 3186     |
# |    total_timesteps  | 2096640  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.02     |
# |    n_updates        | 524134   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8740     |
# |    fps              | 657      |
# |    time_elapsed     | 3188     |
# |    total_timesteps  | 2097600  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.402    |
# |    n_updates        | 524374   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8744     |
# |    fps              | 657      |
# |    time_elapsed     | 3189     |
# |    total_timesteps  | 2098560  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.08     |
# |    n_updates        | 524614   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8748     |
# |    fps              | 657      |
# |    time_elapsed     | 3190     |
# |    total_timesteps  | 2099520  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.626    |
# |    n_updates        | 524854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8752     |
# |    fps              | 657      |
# |    time_elapsed     | 3192     |
# |    total_timesteps  | 2100480  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.605    |
# |    n_updates        | 525094   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8756     |
# |    fps              | 657      |
# |    time_elapsed     | 3194     |
# |    total_timesteps  | 2101440  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.55     |
# |    n_updates        | 525334   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8760     |
# |    fps              | 657      |
# |    time_elapsed     | 3196     |
# |    total_timesteps  | 2102400  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.275    |
# |    n_updates        | 525574   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8764     |
# |    fps              | 657      |
# |    time_elapsed     | 3197     |
# |    total_timesteps  | 2103360  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.799    |
# |    n_updates        | 525814   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8768     |
# |    fps              | 657      |
# |    time_elapsed     | 3198     |
# |    total_timesteps  | 2104320  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.562    |
# |    n_updates        | 526054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8772     |
# |    fps              | 657      |
# |    time_elapsed     | 3200     |
# |    total_timesteps  | 2105280  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.391    |
# |    n_updates        | 526294   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8776     |
# |    fps              | 657      |
# |    time_elapsed     | 3201     |
# |    total_timesteps  | 2106240  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.51     |
# |    n_updates        | 526534   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8780     |
# |    fps              | 657      |
# |    time_elapsed     | 3203     |
# |    total_timesteps  | 2107200  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.01     |
# |    n_updates        | 526774   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8784     |
# |    fps              | 657      |
# |    time_elapsed     | 3204     |
# |    total_timesteps  | 2108160  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.314    |
# |    n_updates        | 527014   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8788     |
# |    fps              | 657      |
# |    time_elapsed     | 3206     |
# |    total_timesteps  | 2109120  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.32     |
# |    n_updates        | 527254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8792     |
# |    fps              | 657      |
# |    time_elapsed     | 3207     |
# |    total_timesteps  | 2110080  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.541    |
# |    n_updates        | 527494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8796     |
# |    fps              | 657      |
# |    time_elapsed     | 3209     |
# |    total_timesteps  | 2111040  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.546    |
# |    n_updates        | 527734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8800     |
# |    fps              | 657      |
# |    time_elapsed     | 3211     |
# |    total_timesteps  | 2112000  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.613    |
# |    n_updates        | 527974   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8804     |
# |    fps              | 657      |
# |    time_elapsed     | 3212     |
# |    total_timesteps  | 2112960  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.657    |
# |    n_updates        | 528214   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8808     |
# |    fps              | 657      |
# |    time_elapsed     | 3213     |
# |    total_timesteps  | 2113920  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.214    |
# |    n_updates        | 528454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8812     |
# |    fps              | 657      |
# |    time_elapsed     | 3215     |
# |    total_timesteps  | 2114880  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.595    |
# |    n_updates        | 528694   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8816     |
# |    fps              | 657      |
# |    time_elapsed     | 3216     |
# |    total_timesteps  | 2115840  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.573    |
# |    n_updates        | 528934   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8820     |
# |    fps              | 657      |
# |    time_elapsed     | 3218     |
# |    total_timesteps  | 2116800  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.35     |
# |    n_updates        | 529174   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8824     |
# |    fps              | 657      |
# |    time_elapsed     | 3219     |
# |    total_timesteps  | 2117760  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.02     |
# |    n_updates        | 529414   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8828     |
# |    fps              | 657      |
# |    time_elapsed     | 3221     |
# |    total_timesteps  | 2118720  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.703    |
# |    n_updates        | 529654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8832     |
# |    fps              | 657      |
# |    time_elapsed     | 3223     |
# |    total_timesteps  | 2119680  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.287    |
# |    n_updates        | 529894   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8836     |
# |    fps              | 657      |
# |    time_elapsed     | 3224     |
# |    total_timesteps  | 2120640  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.274    |
# |    n_updates        | 530134   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8840     |
# |    fps              | 657      |
# |    time_elapsed     | 3226     |
# |    total_timesteps  | 2121600  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.675    |
# |    n_updates        | 530374   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8844     |
# |    fps              | 657      |
# |    time_elapsed     | 3227     |
# |    total_timesteps  | 2122560  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.127    |
# |    n_updates        | 530614   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8848     |
# |    fps              | 657      |
# |    time_elapsed     | 3229     |
# |    total_timesteps  | 2123520  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.354    |
# |    n_updates        | 530854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8852     |
# |    fps              | 657      |
# |    time_elapsed     | 3230     |
# |    total_timesteps  | 2124480  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.406    |
# |    n_updates        | 531094   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8856     |
# |    fps              | 657      |
# |    time_elapsed     | 3231     |
# |    total_timesteps  | 2125440  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.37     |
# |    n_updates        | 531334   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8860     |
# |    fps              | 657      |
# |    time_elapsed     | 3233     |
# |    total_timesteps  | 2126400  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.518    |
# |    n_updates        | 531574   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8864     |
# |    fps              | 657      |
# |    time_elapsed     | 3234     |
# |    total_timesteps  | 2127360  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.168    |
# |    n_updates        | 531814   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8868     |
# |    fps              | 657      |
# |    time_elapsed     | 3236     |
# |    total_timesteps  | 2128320  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.245    |
# |    n_updates        | 532054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8872     |
# |    fps              | 657      |
# |    time_elapsed     | 3238     |
# |    total_timesteps  | 2129280  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.254    |
# |    n_updates        | 532294   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8876     |
# |    fps              | 657      |
# |    time_elapsed     | 3239     |
# |    total_timesteps  | 2130240  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 6.21     |
# |    n_updates        | 532534   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8880     |
# |    fps              | 657      |
# |    time_elapsed     | 3241     |
# |    total_timesteps  | 2131200  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.452    |
# |    n_updates        | 532774   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8884     |
# |    fps              | 657      |
# |    time_elapsed     | 3242     |
# |    total_timesteps  | 2132160  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.5      |
# |    n_updates        | 533014   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8888     |
# |    fps              | 657      |
# |    time_elapsed     | 3244     |
# |    total_timesteps  | 2133120  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.51     |
# |    n_updates        | 533254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8892     |
# |    fps              | 657      |
# |    time_elapsed     | 3245     |
# |    total_timesteps  | 2134080  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.248    |
# |    n_updates        | 533494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8896     |
# |    fps              | 657      |
# |    time_elapsed     | 3246     |
# |    total_timesteps  | 2135040  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.306    |
# |    n_updates        | 533734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8900     |
# |    fps              | 657      |
# |    time_elapsed     | 3248     |
# |    total_timesteps  | 2136000  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.623    |
# |    n_updates        | 533974   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8904     |
# |    fps              | 657      |
# |    time_elapsed     | 3250     |
# |    total_timesteps  | 2136960  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.366    |
# |    n_updates        | 534214   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8908     |
# |    fps              | 657      |
# |    time_elapsed     | 3252     |
# |    total_timesteps  | 2137920  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.499    |
# |    n_updates        | 534454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8912     |
# |    fps              | 657      |
# |    time_elapsed     | 3253     |
# |    total_timesteps  | 2138880  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.379    |
# |    n_updates        | 534694   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8916     |
# |    fps              | 657      |
# |    time_elapsed     | 3254     |
# |    total_timesteps  | 2139840  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.172    |
# |    n_updates        | 534934   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8920     |
# |    fps              | 657      |
# |    time_elapsed     | 3256     |
# |    total_timesteps  | 2140800  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.06     |
# |    n_updates        | 535174   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8924     |
# |    fps              | 657      |
# |    time_elapsed     | 3257     |
# |    total_timesteps  | 2141760  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.83     |
# |    n_updates        | 535414   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8928     |
# |    fps              | 657      |
# |    time_elapsed     | 3258     |
# |    total_timesteps  | 2142720  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.512    |
# |    n_updates        | 535654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8932     |
# |    fps              | 657      |
# |    time_elapsed     | 3260     |
# |    total_timesteps  | 2143680  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.202    |
# |    n_updates        | 535894   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8936     |
# |    fps              | 657      |
# |    time_elapsed     | 3262     |
# |    total_timesteps  | 2144640  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.35     |
# |    n_updates        | 536134   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8940     |
# |    fps              | 657      |
# |    time_elapsed     | 3263     |
# |    total_timesteps  | 2145600  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.27     |
# |    n_updates        | 536374   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8944     |
# |    fps              | 657      |
# |    time_elapsed     | 3265     |
# |    total_timesteps  | 2146560  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.39     |
# |    n_updates        | 536614   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8948     |
# |    fps              | 657      |
# |    time_elapsed     | 3266     |
# |    total_timesteps  | 2147520  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.759    |
# |    n_updates        | 536854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8952     |
# |    fps              | 657      |
# |    time_elapsed     | 3268     |
# |    total_timesteps  | 2148480  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.318    |
# |    n_updates        | 537094   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8956     |
# |    fps              | 657      |
# |    time_elapsed     | 3269     |
# |    total_timesteps  | 2149440  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.538    |
# |    n_updates        | 537334   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8960     |
# |    fps              | 657      |
# |    time_elapsed     | 3270     |
# |    total_timesteps  | 2150400  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.223    |
# |    n_updates        | 537574   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8964     |
# |    fps              | 657      |
# |    time_elapsed     | 3272     |
# |    total_timesteps  | 2151360  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.55     |
# |    n_updates        | 537814   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8968     |
# |    fps              | 657      |
# |    time_elapsed     | 3273     |
# |    total_timesteps  | 2152320  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.189    |
# |    n_updates        | 538054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8972     |
# |    fps              | 657      |
# |    time_elapsed     | 3275     |
# |    total_timesteps  | 2153280  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.162    |
# |    n_updates        | 538294   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8976     |
# |    fps              | 657      |
# |    time_elapsed     | 3277     |
# |    total_timesteps  | 2154240  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.291    |
# |    n_updates        | 538534   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8980     |
# |    fps              | 657      |
# |    time_elapsed     | 3279     |
# |    total_timesteps  | 2155200  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.75     |
# |    n_updates        | 538774   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8984     |
# |    fps              | 657      |
# |    time_elapsed     | 3280     |
# |    total_timesteps  | 2156160  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.421    |
# |    n_updates        | 539014   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8988     |
# |    fps              | 657      |
# |    time_elapsed     | 3281     |
# |    total_timesteps  | 2157120  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.69     |
# |    n_updates        | 539254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8992     |
# |    fps              | 657      |
# |    time_elapsed     | 3283     |
# |    total_timesteps  | 2158080  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.283    |
# |    n_updates        | 539494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 8996     |
# |    fps              | 657      |
# |    time_elapsed     | 3284     |
# |    total_timesteps  | 2159040  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 6.52     |
# |    n_updates        | 539734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9000     |
# |    fps              | 657      |
# |    time_elapsed     | 3286     |
# |    total_timesteps  | 2160000  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.656    |
# |    n_updates        | 539974   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9004     |
# |    fps              | 657      |
# |    time_elapsed     | 3287     |
# |    total_timesteps  | 2160960  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.757    |
# |    n_updates        | 540214   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9008     |
# |    fps              | 657      |
# |    time_elapsed     | 3289     |
# |    total_timesteps  | 2161920  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.435    |
# |    n_updates        | 540454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9012     |
# |    fps              | 657      |
# |    time_elapsed     | 3291     |
# |    total_timesteps  | 2162880  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.596    |
# |    n_updates        | 540694   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9016     |
# |    fps              | 657      |
# |    time_elapsed     | 3292     |
# |    total_timesteps  | 2163840  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.535    |
# |    n_updates        | 540934   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9020     |
# |    fps              | 657      |
# |    time_elapsed     | 3293     |
# |    total_timesteps  | 2164800  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.582    |
# |    n_updates        | 541174   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9024     |
# |    fps              | 657      |
# |    time_elapsed     | 3295     |
# |    total_timesteps  | 2165760  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.5      |
# |    n_updates        | 541414   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9028     |
# |    fps              | 657      |
# |    time_elapsed     | 3296     |
# |    total_timesteps  | 2166720  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.554    |
# |    n_updates        | 541654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9032     |
# |    fps              | 657      |
# |    time_elapsed     | 3298     |
# |    total_timesteps  | 2167680  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.23     |
# |    n_updates        | 541894   |
# ----------------------------------
# ...
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.407    |
# |    n_updates        | 592774   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9884     |
# |    fps              | 655      |
# |    time_elapsed     | 3619     |
# |    total_timesteps  | 2372160  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.315    |
# |    n_updates        | 593014   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9888     |
# |    fps              | 655      |
# |    time_elapsed     | 3621     |
# |    total_timesteps  | 2373120  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.441    |
# |    n_updates        | 593254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9892     |
# |    fps              | 655      |
# |    time_elapsed     | 3622     |
# |    total_timesteps  | 2374080  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.727    |
# |    n_updates        | 593494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9896     |
# |    fps              | 655      |
# |    time_elapsed     | 3624     |
# |    total_timesteps  | 2375040  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.679    |
# |    n_updates        | 593734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9900     |
# |    fps              | 655      |
# |    time_elapsed     | 3625     |
# |    total_timesteps  | 2376000  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.644    |
# |    n_updates        | 593974   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9904     |
# |    fps              | 655      |
# |    time_elapsed     | 3627     |
# |    total_timesteps  | 2376960  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.452    |
# |    n_updates        | 594214   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9908     |
# |    fps              | 655      |
# |    time_elapsed     | 3629     |
# |    total_timesteps  | 2377920  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.517    |
# |    n_updates        | 594454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9912     |
# |    fps              | 655      |
# |    time_elapsed     | 3630     |
# |    total_timesteps  | 2378880  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.544    |
# |    n_updates        | 594694   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9916     |
# |    fps              | 655      |
# |    time_elapsed     | 3632     |
# |    total_timesteps  | 2379840  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.873    |
# |    n_updates        | 594934   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9920     |
# |    fps              | 655      |
# |    time_elapsed     | 3633     |
# |    total_timesteps  | 2380800  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.3      |
# |    n_updates        | 595174   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9924     |
# |    fps              | 655      |
# |    time_elapsed     | 3634     |
# |    total_timesteps  | 2381760  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.06     |
# |    n_updates        | 595414   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9928     |
# |    fps              | 655      |
# |    time_elapsed     | 3636     |
# |    total_timesteps  | 2382720  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.427    |
# |    n_updates        | 595654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9932     |
# |    fps              | 655      |
# |    time_elapsed     | 3637     |
# |    total_timesteps  | 2383680  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.818    |
# |    n_updates        | 595894   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9936     |
# |    fps              | 655      |
# |    time_elapsed     | 3638     |
# |    total_timesteps  | 2384640  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.18     |
# |    n_updates        | 596134   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9940     |
# |    fps              | 655      |
# |    time_elapsed     | 3640     |
# |    total_timesteps  | 2385600  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.603    |
# |    n_updates        | 596374   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9944     |
# |    fps              | 655      |
# |    time_elapsed     | 3642     |
# |    total_timesteps  | 2386560  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.675    |
# |    n_updates        | 596614   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9948     |
# |    fps              | 655      |
# |    time_elapsed     | 3644     |
# |    total_timesteps  | 2387520  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.817    |
# |    n_updates        | 596854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9952     |
# |    fps              | 655      |
# |    time_elapsed     | 3645     |
# |    total_timesteps  | 2388480  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.769    |
# |    n_updates        | 597094   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9956     |
# |    fps              | 655      |
# |    time_elapsed     | 3646     |
# |    total_timesteps  | 2389440  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.417    |
# |    n_updates        | 597334   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9960     |
# |    fps              | 655      |
# |    time_elapsed     | 3648     |
# |    total_timesteps  | 2390400  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.234    |
# |    n_updates        | 597574   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9964     |
# |    fps              | 655      |
# |    time_elapsed     | 3649     |
# |    total_timesteps  | 2391360  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.2      |
# |    n_updates        | 597814   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9968     |
# |    fps              | 655      |
# |    time_elapsed     | 3650     |
# |    total_timesteps  | 2392320  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.872    |
# |    n_updates        | 598054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 172      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9972     |
# |    fps              | 655      |
# |    time_elapsed     | 3652     |
# |    total_timesteps  | 2393280  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.468    |
# |    n_updates        | 598294   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9976     |
# |    fps              | 655      |
# |    time_elapsed     | 3653     |
# |    total_timesteps  | 2394240  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.632    |
# |    n_updates        | 598534   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9980     |
# |    fps              | 655      |
# |    time_elapsed     | 3655     |
# |    total_timesteps  | 2395200  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.451    |
# |    n_updates        | 598774   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9984     |
# |    fps              | 655      |
# |    time_elapsed     | 3657     |
# |    total_timesteps  | 2396160  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.468    |
# |    n_updates        | 599014   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 172      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9988     |
# |    fps              | 655      |
# |    time_elapsed     | 3659     |
# |    total_timesteps  | 2397120  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.452    |
# |    n_updates        | 599254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9992     |
# |    fps              | 655      |
# |    time_elapsed     | 3660     |
# |    total_timesteps  | 2398080  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.28     |
# |    n_updates        | 599494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 9996     |
# |    fps              | 655      |
# |    time_elapsed     | 3661     |
# |    total_timesteps  | 2399040  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.539    |
# |    n_updates        | 599734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 10000    |
# |    fps              | 655      |
# |    time_elapsed     | 3663     |
# |    total_timesteps  | 2400000  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.703    |
# |    n_updates        | 599974   |
# ----------------------------------
# Analysis results saved to 'dqn_analysis_results.csv'.
