# %%
# !pip install gymnasium
# !pip install stable-baselines3[extra]
# !pip install tensorboard
# %load_ext tensorboard
# !pip install torch --upgrade --force-reinstall
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: stable-baselines3[extra] in /usr/local/lib/python3.10/dist-packages (2.4.1)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: numpy<2.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.5.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (3.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (3.10.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.10.0.84)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.17.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (13.9.4)
# Requirement already satisfied: ale-py>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (0.10.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (11.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from ale-py>=0.9.0->stable-baselines3[extra]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.69.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (4.25.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (75.1.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.13->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3[extra]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3[extra]) (2024.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.2)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.69.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.7)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboard) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (4.25.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (75.1.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Collecting torch
#   Using cached torch-2.5.1-cp310-cp310-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting filelock (from torch)
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.8.0 (from torch)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting networkx (from torch)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Using cached jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch)
#   Using cached fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Using cached nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch)
#   Using cached nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch)
#   Using cached triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting sympy==1.13.1 (from torch)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Using cached MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Using cached torch-2.5.1-cp310-cp310-manylinux1_x86_64.whl (906.4 MB)
# Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
# Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
# Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
# Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
# Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
# Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
# Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
# Using cached nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
# Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Using cached nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Using cached triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Using cached fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Using cached jinja2-3.1.5-py3-none-any.whl (134 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, typing-extensions, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, MarkupSafe, fsspec, filelock, triton, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, torch
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.4.127
#     Uninstalling nvidia-nvjitlink-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.4.127
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.5.147
#     Uninstalling nvidia-curand-cu12-10.3.5.147:
#       Successfully uninstalled nvidia-curand-cu12-10.3.5.147
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.1.3
#     Uninstalling nvidia-cufft-cu12-11.2.1.3:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.1.3
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.4.127
#     Uninstalling nvidia-cuda-runtime-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.4.127
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.4.127
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.4.127
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.4.127
#     Uninstalling nvidia-cuda-cupti-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.4.127
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.4.5.8
#     Uninstalling nvidia-cublas-cu12-12.4.5.8:
#       Successfully uninstalled nvidia-cublas-cu12-12.4.5.8
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.4.2
#     Uninstalling networkx-3.4.2:
#       Successfully uninstalled networkx-3.4.2
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.12.0
#     Uninstalling fsspec-2024.12.0:
#       Successfully uninstalled fsspec-2024.12.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.16.1
#     Uninstalling filelock-3.16.1:
#       Successfully uninstalled filelock-3.16.1
#   Attempting uninstall: triton
#     Found existing installation: triton 3.1.0
#     Uninstalling triton-3.1.0:
#       Successfully uninstalled triton-3.1.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.3.1.170
#     Uninstalling nvidia-cusparse-cu12-12.3.1.170:
#       Successfully uninstalled nvidia-cusparse-cu12-12.3.1.170
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.1.0.70
#     Uninstalling nvidia-cudnn-cu12-9.1.0.70:
#       Successfully uninstalled nvidia-cudnn-cu12-9.1.0.70
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.5
#     Uninstalling Jinja2-3.1.5:
#       Successfully uninstalled Jinja2-3.1.5
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.1.9
#     Uninstalling nvidia-cusolver-cu12-11.6.1.9:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.1.9
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1
#     Uninstalling torch-2.5.1:
#       Successfully uninstalled torch-2.5.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed MarkupSafe-3.0.2 filelock-3.16.1 fsspec-2024.12.0 jinja2-3.1.5 mpmath-1.3.0 networkx-3.4.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 sympy-1.13.1 torch-2.5.1 triton-3.1.0 typing-extensions-4.12.2

# %% [markdown]
# # **DQN agent with simple binary rewards for storage volume constraints with smaller time steps (threshold) each episode**

# %%
# Import necessary libraries
import os
import numpy as np
import pandas as pd
import torch as th
import gymnasium
from gymnasium import Env
from gymnasium.spaces import Discrete, Box
from stable_baselines3 import DQN
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# Define storage and release limits
min_storage_af = 500000
max_storage_af = 1600000
initial_storage_af = 500000
target_storage_af = (min_storage_af + max_storage_af) / 2
release_cfs = [1000, 2000, 4000]  # Define discrete release values (cfs)
release_af = [r * 1.98211 for r in release_cfs]  # Convert cfs to acre-feet

# Define the custom Reservoir environment
class ReservoirEnv(Env):
    def __init__(self, data, scaler, episode_length=365):
        super(ReservoirEnv, self).__init__()
        self.data = data
        self.scaler = scaler
        self.episode_length = episode_length
        self.current_step = 0
        self.storage_history = []
        self.predicted_release_history = []
        self.reward_history = []
        self.q_values = []

        # Unscaled data for actual values
        unscaled_data = self.scaler.inverse_transform(self.data)
        self.actual_storage_history = unscaled_data[:, 0].tolist()
        self.actual_release_history = unscaled_data[:, 3].tolist()
        self.evaporation_history = unscaled_data[:, 1].tolist()
        self.inflow_history = unscaled_data[:, 2].tolist()

        # Define action space and observation space
        self.action_space = Discrete(len(release_af))  # Actions: release values in af
        self.observation_space = Box(low=0, high=1, shape=(3,), dtype=np.float32)

    def reset(self, seed=None):
        self.current_step = np.random.randint(0, len(self.data) - self.episode_length)
        self.storage_history.clear()
        self.predicted_release_history.clear()
        self.reward_history.clear()
        self.q_values.clear()

        # Set the storage to the value corresponding to the start of the episode
        self.current_storage = self.scaler.inverse_transform(self.data[self.current_step:self.current_step + 1, :])[0, 0]
        self.storage_history.append(self.current_storage)
        return self._get_observation(), {}

    def _get_observation(self):
        return self.data[self.current_step, :3]

    def step(self, action):
        release_af_value = release_af[action]  # Map action index to release value
        inflow_af = self.scaler.inverse_transform(self.data[self.current_step:self.current_step + 1, :])[0, 2]
        evaporation_af = self.scaler.inverse_transform(self.data[self.current_step:self.current_step + 1, :])[0, 1]

        # Update storage with inflow, evaporation, and release
        self.current_storage += inflow_af - evaporation_af - release_af_value
        self.predicted_release_history.append(release_af_value)
        self.storage_history.append(self.current_storage)

        # Reward calculation
        if min_storage_af <= self.current_storage <= max_storage_af:
            reward = 1  # Positive reward for staying within bounds
        else:
            reward = -1  # Negative reward for going out of bounds

        self.reward_history.append(reward)
        self.current_step += 1
        done = self.current_step >= len(self.data) or (self.current_step % self.episode_length == 0)
        observation = self._get_observation() if not done else np.zeros(3)
        return observation, reward, done, False, {}

    def render(self, mode='human', close=False):
        pass


# Load and preprocess data
data = pd.read_csv('/content/Clipped_NAVAJORESERVOIR08-18-2024T16.48.23.csv')
storage = data['Storage (af)'].values
evaporation = data['Evaporation (af)'].values
inflow_cfs = data['Inflow** (cfs)'].values
release_cfs = data['Total Release (cfs)'].values
dataset = np.column_stack((storage, evaporation, inflow_cfs * 1.98211, release_cfs * 1.98211))
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(dataset)

# Set up environment
episode_length = 365
env = ReservoirEnv(scaled_data, scaler, episode_length=episode_length)

# Initializing DQN model
# model = DQN(
#     "MlpPolicy",
#     env,
#     learning_rate=0.0001,
#     batch_size=128,
#     gamma=0.99,
#     exploration_fraction=0.1,
#     exploration_final_eps=0.01,
#     target_update_interval=100,
#     train_freq=4,
#     verbose=1,
# )

model = DQN("MlpPolicy", env, verbose=1)

# Training the model
n_episodes = 10000
total_timesteps = n_episodes * episode_length
model.learn(total_timesteps=total_timesteps)

# Saving the model
model.save("dqn_reservoir_agent")
# Out:
# Streaming output truncated to the last 5000 lines.
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.06     |
# |    n_updates        | 852290   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 202      |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18492    |
# |    fps              | 578      |
# |    time_elapsed     | 5891     |
# |    total_timesteps  | 3410306  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.48     |
# |    n_updates        | 852551   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18496    |
# |    fps              | 578      |
# |    time_elapsed     | 5893     |
# |    total_timesteps  | 3410999  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.627    |
# |    n_updates        | 852724   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18500    |
# |    fps              | 578      |
# |    time_elapsed     | 5893     |
# |    total_timesteps  | 3411306  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.34     |
# |    n_updates        | 852801   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18504    |
# |    fps              | 578      |
# |    time_elapsed     | 5895     |
# |    total_timesteps  | 3412268  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.24     |
# |    n_updates        | 853041   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18508    |
# |    fps              | 578      |
# |    time_elapsed     | 5896     |
# |    total_timesteps  | 3412888  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.86     |
# |    n_updates        | 853196   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18512    |
# |    fps              | 578      |
# |    time_elapsed     | 5896     |
# |    total_timesteps  | 3413226  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.875    |
# |    n_updates        | 853281   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18516    |
# |    fps              | 578      |
# |    time_elapsed     | 5898     |
# |    total_timesteps  | 3414053  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.388    |
# |    n_updates        | 853488   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18520    |
# |    fps              | 578      |
# |    time_elapsed     | 5899     |
# |    total_timesteps  | 3414736  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.339    |
# |    n_updates        | 853658   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18524    |
# |    fps              | 578      |
# |    time_elapsed     | 5900     |
# |    total_timesteps  | 3415433  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.45     |
# |    n_updates        | 853833   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18528    |
# |    fps              | 578      |
# |    time_elapsed     | 5901     |
# |    total_timesteps  | 3416280  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.299    |
# |    n_updates        | 854044   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18532    |
# |    fps              | 578      |
# |    time_elapsed     | 5903     |
# |    total_timesteps  | 3417302  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.553    |
# |    n_updates        | 854300   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 181      |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18536    |
# |    fps              | 578      |
# |    time_elapsed     | 5904     |
# |    total_timesteps  | 3417825  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.184    |
# |    n_updates        | 854431   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18540    |
# |    fps              | 578      |
# |    time_elapsed     | 5906     |
# |    total_timesteps  | 3418718  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.61     |
# |    n_updates        | 854654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18544    |
# |    fps              | 578      |
# |    time_elapsed     | 5908     |
# |    total_timesteps  | 3419783  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.384    |
# |    n_updates        | 854920   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18548    |
# |    fps              | 578      |
# |    time_elapsed     | 5909     |
# |    total_timesteps  | 3420505  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.477    |
# |    n_updates        | 855101   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18552    |
# |    fps              | 578      |
# |    time_elapsed     | 5910     |
# |    total_timesteps  | 3420833  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.241    |
# |    n_updates        | 855183   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18556    |
# |    fps              | 578      |
# |    time_elapsed     | 5911     |
# |    total_timesteps  | 3421766  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.379    |
# |    n_updates        | 855416   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18560    |
# |    fps              | 578      |
# |    time_elapsed     | 5912     |
# |    total_timesteps  | 3422275  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.442    |
# |    n_updates        | 855543   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18564    |
# |    fps              | 578      |
# |    time_elapsed     | 5914     |
# |    total_timesteps  | 3423316  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.587    |
# |    n_updates        | 855803   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18568    |
# |    fps              | 578      |
# |    time_elapsed     | 5915     |
# |    total_timesteps  | 3424205  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.735    |
# |    n_updates        | 856026   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18572    |
# |    fps              | 578      |
# |    time_elapsed     | 5916     |
# |    total_timesteps  | 3424734  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.486    |
# |    n_updates        | 856158   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18576    |
# |    fps              | 578      |
# |    time_elapsed     | 5917     |
# |    total_timesteps  | 3425152  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.784    |
# |    n_updates        | 856262   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18580    |
# |    fps              | 578      |
# |    time_elapsed     | 5919     |
# |    total_timesteps  | 3426239  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.531    |
# |    n_updates        | 856534   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18584    |
# |    fps              | 578      |
# |    time_elapsed     | 5921     |
# |    total_timesteps  | 3426929  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.175    |
# |    n_updates        | 856707   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 186      |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18588    |
# |    fps              | 578      |
# |    time_elapsed     | 5922     |
# |    total_timesteps  | 3427822  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.457    |
# |    n_updates        | 856930   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18592    |
# |    fps              | 578      |
# |    time_elapsed     | 5923     |
# |    total_timesteps  | 3428508  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.631    |
# |    n_updates        | 857101   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18596    |
# |    fps              | 578      |
# |    time_elapsed     | 5925     |
# |    total_timesteps  | 3429369  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.62     |
# |    n_updates        | 857317   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18600    |
# |    fps              | 578      |
# |    time_elapsed     | 5926     |
# |    total_timesteps  | 3430211  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.17     |
# |    n_updates        | 857527   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18604    |
# |    fps              | 578      |
# |    time_elapsed     | 5928     |
# |    total_timesteps  | 3431116  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.555    |
# |    n_updates        | 857753   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18608    |
# |    fps              | 578      |
# |    time_elapsed     | 5929     |
# |    total_timesteps  | 3432118  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.647    |
# |    n_updates        | 858004   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18612    |
# |    fps              | 578      |
# |    time_elapsed     | 5931     |
# |    total_timesteps  | 3433157  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.587    |
# |    n_updates        | 858264   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18616    |
# |    fps              | 578      |
# |    time_elapsed     | 5932     |
# |    total_timesteps  | 3433768  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.224    |
# |    n_updates        | 858416   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18620    |
# |    fps              | 578      |
# |    time_elapsed     | 5934     |
# |    total_timesteps  | 3434548  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.472    |
# |    n_updates        | 858611   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 178      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18624    |
# |    fps              | 578      |
# |    time_elapsed     | 5936     |
# |    total_timesteps  | 3435290  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.26     |
# |    n_updates        | 858797   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18628    |
# |    fps              | 578      |
# |    time_elapsed     | 5937     |
# |    total_timesteps  | 3435997  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.598    |
# |    n_updates        | 858974   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 170      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18632    |
# |    fps              | 578      |
# |    time_elapsed     | 5938     |
# |    total_timesteps  | 3436863  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.746    |
# |    n_updates        | 859190   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 171      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18636    |
# |    fps              | 578      |
# |    time_elapsed     | 5939     |
# |    total_timesteps  | 3437509  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.416    |
# |    n_updates        | 859352   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18640    |
# |    fps              | 578      |
# |    time_elapsed     | 5940     |
# |    total_timesteps  | 3438086  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.1      |
# |    n_updates        | 859496   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18644    |
# |    fps              | 578      |
# |    time_elapsed     | 5941     |
# |    total_timesteps  | 3438718  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.78     |
# |    n_updates        | 859654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18648    |
# |    fps              | 578      |
# |    time_elapsed     | 5942     |
# |    total_timesteps  | 3439293  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.452    |
# |    n_updates        | 859798   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18652    |
# |    fps              | 578      |
# |    time_elapsed     | 5943     |
# |    total_timesteps  | 3439965  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.16     |
# |    n_updates        | 859966   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18656    |
# |    fps              | 578      |
# |    time_elapsed     | 5944     |
# |    total_timesteps  | 3440531  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.283    |
# |    n_updates        | 860107   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18660    |
# |    fps              | 578      |
# |    time_elapsed     | 5945     |
# |    total_timesteps  | 3441120  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.61     |
# |    n_updates        | 860254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18664    |
# |    fps              | 578      |
# |    time_elapsed     | 5947     |
# |    total_timesteps  | 3442048  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.83     |
# |    n_updates        | 860486   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18668    |
# |    fps              | 578      |
# |    time_elapsed     | 5949     |
# |    total_timesteps  | 3443149  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.591    |
# |    n_updates        | 860762   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18672    |
# |    fps              | 578      |
# |    time_elapsed     | 5951     |
# |    total_timesteps  | 3443596  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.478    |
# |    n_updates        | 860873   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18676    |
# |    fps              | 578      |
# |    time_elapsed     | 5952     |
# |    total_timesteps  | 3444389  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.286    |
# |    n_updates        | 861072   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 190      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18680    |
# |    fps              | 578      |
# |    time_elapsed     | 5954     |
# |    total_timesteps  | 3445255  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.75     |
# |    n_updates        | 861288   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18684    |
# |    fps              | 578      |
# |    time_elapsed     | 5955     |
# |    total_timesteps  | 3446116  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.286    |
# |    n_updates        | 861503   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18688    |
# |    fps              | 578      |
# |    time_elapsed     | 5957     |
# |    total_timesteps  | 3447006  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.305    |
# |    n_updates        | 861726   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 191      |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18692    |
# |    fps              | 578      |
# |    time_elapsed     | 5958     |
# |    total_timesteps  | 3447601  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.245    |
# |    n_updates        | 861875   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 187      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18696    |
# |    fps              | 578      |
# |    time_elapsed     | 5959     |
# |    total_timesteps  | 3448039  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.244    |
# |    n_updates        | 861984   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18700    |
# |    fps              | 578      |
# |    time_elapsed     | 5959     |
# |    total_timesteps  | 3448385  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.286    |
# |    n_updates        | 862071   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18704    |
# |    fps              | 578      |
# |    time_elapsed     | 5960     |
# |    total_timesteps  | 3449122  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.303    |
# |    n_updates        | 862255   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 179      |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18708    |
# |    fps              | 578      |
# |    time_elapsed     | 5962     |
# |    total_timesteps  | 3450023  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.435    |
# |    n_updates        | 862480   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18712    |
# |    fps              | 578      |
# |    time_elapsed     | 5963     |
# |    total_timesteps  | 3450769  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.44     |
# |    n_updates        | 862667   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18716    |
# |    fps              | 578      |
# |    time_elapsed     | 5965     |
# |    total_timesteps  | 3451572  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.124    |
# |    n_updates        | 862867   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18720    |
# |    fps              | 578      |
# |    time_elapsed     | 5966     |
# |    total_timesteps  | 3452357  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.148    |
# |    n_updates        | 863064   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18724    |
# |    fps              | 578      |
# |    time_elapsed     | 5967     |
# |    total_timesteps  | 3452789  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.21     |
# |    n_updates        | 863172   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18728    |
# |    fps              | 578      |
# |    time_elapsed     | 5968     |
# |    total_timesteps  | 3453432  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.216    |
# |    n_updates        | 863332   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 169      |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18732    |
# |    fps              | 578      |
# |    time_elapsed     | 5969     |
# |    total_timesteps  | 3453770  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.337    |
# |    n_updates        | 863417   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18736    |
# |    fps              | 578      |
# |    time_elapsed     | 5970     |
# |    total_timesteps  | 3454734  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.311    |
# |    n_updates        | 863658   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18740    |
# |    fps              | 578      |
# |    time_elapsed     | 5972     |
# |    total_timesteps  | 3455541  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.137    |
# |    n_updates        | 863860   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18744    |
# |    fps              | 578      |
# |    time_elapsed     | 5973     |
# |    total_timesteps  | 3456682  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.287    |
# |    n_updates        | 864145   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18748    |
# |    fps              | 578      |
# |    time_elapsed     | 5974     |
# |    total_timesteps  | 3456973  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.573    |
# |    n_updates        | 864218   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18752    |
# |    fps              | 578      |
# |    time_elapsed     | 5975     |
# |    total_timesteps  | 3457471  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.656    |
# |    n_updates        | 864342   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18756    |
# |    fps              | 578      |
# |    time_elapsed     | 5975     |
# |    total_timesteps  | 3457961  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.237    |
# |    n_updates        | 864465   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18760    |
# |    fps              | 578      |
# |    time_elapsed     | 5976     |
# |    total_timesteps  | 3458642  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.195    |
# |    n_updates        | 864635   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 169      |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18764    |
# |    fps              | 578      |
# |    time_elapsed     | 5977     |
# |    total_timesteps  | 3458954  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.176    |
# |    n_updates        | 864713   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 167      |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18768    |
# |    fps              | 578      |
# |    time_elapsed     | 5979     |
# |    total_timesteps  | 3459830  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.649    |
# |    n_updates        | 864932   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 169      |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18772    |
# |    fps              | 578      |
# |    time_elapsed     | 5980     |
# |    total_timesteps  | 3460511  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.02     |
# |    n_updates        | 865102   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 167      |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18776    |
# |    fps              | 578      |
# |    time_elapsed     | 5982     |
# |    total_timesteps  | 3461132  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.22     |
# |    n_updates        | 865257   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18780    |
# |    fps              | 578      |
# |    time_elapsed     | 5984     |
# |    total_timesteps  | 3462433  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.291    |
# |    n_updates        | 865583   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18784    |
# |    fps              | 578      |
# |    time_elapsed     | 5985     |
# |    total_timesteps  | 3463221  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.282    |
# |    n_updates        | 865780   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 166      |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18788    |
# |    fps              | 578      |
# |    time_elapsed     | 5986     |
# |    total_timesteps  | 3463637  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.249    |
# |    n_updates        | 865884   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 170      |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18792    |
# |    fps              | 578      |
# |    time_elapsed     | 5987     |
# |    total_timesteps  | 3464564  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.318    |
# |    n_updates        | 866115   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18796    |
# |    fps              | 578      |
# |    time_elapsed     | 5988     |
# |    total_timesteps  | 3465098  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.151    |
# |    n_updates        | 866249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18800    |
# |    fps              | 578      |
# |    time_elapsed     | 5989     |
# |    total_timesteps  | 3465668  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.199    |
# |    n_updates        | 866391   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18804    |
# |    fps              | 578      |
# |    time_elapsed     | 5990     |
# |    total_timesteps  | 3466656  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.91     |
# |    n_updates        | 866638   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18808    |
# |    fps              | 578      |
# |    time_elapsed     | 5992     |
# |    total_timesteps  | 3467614  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.368    |
# |    n_updates        | 866878   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18812    |
# |    fps              | 578      |
# |    time_elapsed     | 5993     |
# |    total_timesteps  | 3468067  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.492    |
# |    n_updates        | 866991   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18816    |
# |    fps              | 578      |
# |    time_elapsed     | 5995     |
# |    total_timesteps  | 3468729  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.708    |
# |    n_updates        | 867157   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18820    |
# |    fps              | 578      |
# |    time_elapsed     | 5996     |
# |    total_timesteps  | 3469734  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.36     |
# |    n_updates        | 867408   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18824    |
# |    fps              | 578      |
# |    time_elapsed     | 5997     |
# |    total_timesteps  | 3470343  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.477    |
# |    n_updates        | 867560   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18828    |
# |    fps              | 578      |
# |    time_elapsed     | 5998     |
# |    total_timesteps  | 3470796  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.445    |
# |    n_updates        | 867673   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18832    |
# |    fps              | 578      |
# |    time_elapsed     | 5999     |
# |    total_timesteps  | 3471418  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.305    |
# |    n_updates        | 867829   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18836    |
# |    fps              | 578      |
# |    time_elapsed     | 6001     |
# |    total_timesteps  | 3472561  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.645    |
# |    n_updates        | 868115   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 179      |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18840    |
# |    fps              | 578      |
# |    time_elapsed     | 6002     |
# |    total_timesteps  | 3473427  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.274    |
# |    n_updates        | 868331   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18844    |
# |    fps              | 578      |
# |    time_elapsed     | 6003     |
# |    total_timesteps  | 3474032  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.22     |
# |    n_updates        | 868482   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18848    |
# |    fps              | 578      |
# |    time_elapsed     | 6004     |
# |    total_timesteps  | 3474522  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.434    |
# |    n_updates        | 868605   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 18852    |
# |    fps              | 578      |
# |    time_elapsed     | 6005     |
# |    total_timesteps  | 3475243  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.509    |
# |    n_updates        | 868785   |
# ...
# |    time_elapsed     | 6271     |
# |    total_timesteps  | 3628192  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.44     |
# |    n_updates        | 907022   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19704    |
# |    fps              | 578      |
# |    time_elapsed     | 6272     |
# |    total_timesteps  | 3629196  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.364    |
# |    n_updates        | 907273   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19708    |
# |    fps              | 578      |
# |    time_elapsed     | 6273     |
# |    total_timesteps  | 3629863  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.583    |
# |    n_updates        | 907440   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19712    |
# |    fps              | 578      |
# |    time_elapsed     | 6274     |
# |    total_timesteps  | 3630260  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.345    |
# |    n_updates        | 907539   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 171      |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19716    |
# |    fps              | 578      |
# |    time_elapsed     | 6275     |
# |    total_timesteps  | 3630861  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.455    |
# |    n_updates        | 907690   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 166      |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19720    |
# |    fps              | 578      |
# |    time_elapsed     | 6276     |
# |    total_timesteps  | 3631247  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.8      |
# |    n_updates        | 907786   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 169      |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19724    |
# |    fps              | 578      |
# |    time_elapsed     | 6278     |
# |    total_timesteps  | 3632210  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.26     |
# |    n_updates        | 908027   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 170      |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19728    |
# |    fps              | 578      |
# |    time_elapsed     | 6279     |
# |    total_timesteps  | 3632897  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.525    |
# |    n_updates        | 908199   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 166      |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19732    |
# |    fps              | 578      |
# |    time_elapsed     | 6280     |
# |    total_timesteps  | 3633505  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.444    |
# |    n_updates        | 908351   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 166      |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19736    |
# |    fps              | 578      |
# |    time_elapsed     | 6281     |
# |    total_timesteps  | 3634301  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.24     |
# |    n_updates        | 908550   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 167      |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19740    |
# |    fps              | 578      |
# |    time_elapsed     | 6282     |
# |    total_timesteps  | 3634970  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.294    |
# |    n_updates        | 908717   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19744    |
# |    fps              | 578      |
# |    time_elapsed     | 6284     |
# |    total_timesteps  | 3636044  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.291    |
# |    n_updates        | 908985   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19748    |
# |    fps              | 578      |
# |    time_elapsed     | 6286     |
# |    total_timesteps  | 3636989  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.1      |
# |    n_updates        | 909222   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 177      |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19752    |
# |    fps              | 578      |
# |    time_elapsed     | 6287     |
# |    total_timesteps  | 3637665  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.269    |
# |    n_updates        | 909391   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19756    |
# |    fps              | 578      |
# |    time_elapsed     | 6288     |
# |    total_timesteps  | 3638431  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.421    |
# |    n_updates        | 909582   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19760    |
# |    fps              | 578      |
# |    time_elapsed     | 6290     |
# |    total_timesteps  | 3639373  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.387    |
# |    n_updates        | 909818   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 181      |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19764    |
# |    fps              | 578      |
# |    time_elapsed     | 6291     |
# |    total_timesteps  | 3639978  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.641    |
# |    n_updates        | 909969   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19768    |
# |    fps              | 578      |
# |    time_elapsed     | 6293     |
# |    total_timesteps  | 3641048  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.815    |
# |    n_updates        | 910236   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19772    |
# |    fps              | 578      |
# |    time_elapsed     | 6294     |
# |    total_timesteps  | 3641680  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.592    |
# |    n_updates        | 910394   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 181      |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19776    |
# |    fps              | 578      |
# |    time_elapsed     | 6295     |
# |    total_timesteps  | 3642305  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.612    |
# |    n_updates        | 910551   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19780    |
# |    fps              | 578      |
# |    time_elapsed     | 6296     |
# |    total_timesteps  | 3642992  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.1      |
# |    n_updates        | 910722   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 189      |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19784    |
# |    fps              | 578      |
# |    time_elapsed     | 6298     |
# |    total_timesteps  | 3643852  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.679    |
# |    n_updates        | 910937   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 188      |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19788    |
# |    fps              | 578      |
# |    time_elapsed     | 6299     |
# |    total_timesteps  | 3644563  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.406    |
# |    n_updates        | 911115   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19792    |
# |    fps              | 578      |
# |    time_elapsed     | 6300     |
# |    total_timesteps  | 3644999  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.965    |
# |    n_updates        | 911224   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 184      |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19796    |
# |    fps              | 578      |
# |    time_elapsed     | 6301     |
# |    total_timesteps  | 3645541  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.473    |
# |    n_updates        | 911360   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 179      |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19800    |
# |    fps              | 578      |
# |    time_elapsed     | 6301     |
# |    total_timesteps  | 3646096  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.424    |
# |    n_updates        | 911498   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19804    |
# |    fps              | 578      |
# |    time_elapsed     | 6302     |
# |    total_timesteps  | 3646634  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.374    |
# |    n_updates        | 911633   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19808    |
# |    fps              | 578      |
# |    time_elapsed     | 6304     |
# |    total_timesteps  | 3647403  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.529    |
# |    n_updates        | 911825   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19812    |
# |    fps              | 578      |
# |    time_elapsed     | 6306     |
# |    total_timesteps  | 3648107  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.26     |
# |    n_updates        | 912001   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 181      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19816    |
# |    fps              | 578      |
# |    time_elapsed     | 6307     |
# |    total_timesteps  | 3649001  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.244    |
# |    n_updates        | 912225   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 185      |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 19820    |
# |    fps              | 578      |
# |    time_elapsed     | 6308     |
# |    total_timesteps  | 3649772  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.497    |
# |    n_updates        | 912417   |
# ----------------------------------

# %%
# Load the trained DQN agent
model = DQN.load("dqn_reservoir_agent")

# Reset the environment and initialize analysis lists
env = ReservoirEnv(scaled_data, scaler, episode_length=episode_length)
obs, _ = env.reset()

predicted_releases = []
actual_releases = []
predicted_storage = []
actual_storage = []
rewards = []
q_values = []

# Simulate the entire dataset
env.current_step = 0  # Start from the beginning of the dataset
done = False

while env.current_step < len(env.data):
    action, _ = model.predict(obs, deterministic=True)  # Get action from DQN agent
    obs, reward, done, _, _ = env.step(action)  # Step through the environment

    # Capture data for analysis
    predicted_releases.append(env.predicted_release_history[-1])
    actual_releases.append(env.actual_release_history[env.current_step - 1])
    predicted_storage.append(env.storage_history[-1])
    actual_storage.append(env.actual_storage_history[env.current_step - 1])
    rewards.append(reward)

    # Compute Q-values for the current observation
    q_value = model.q_net(th.tensor(obs, dtype=th.float32).unsqueeze(0)).detach().numpy().max()
    q_values.append(q_value)

    # Stop if the end of the dataset is reached
    if env.current_step >= len(env.data) - 1:
        break

# Save analysis results to CSV
results_df = pd.DataFrame({
    "Time Step": range(len(predicted_releases)),
    "Predicted Releases (af)": predicted_releases,
    "Actual Releases (af)": actual_releases,
    "Predicted Storage (af)": predicted_storage,
    "Actual Storage (af)": actual_storage,
    "Rewards": rewards,
    "Q Values": q_values,
})
results_df.to_csv("dqn_analysis_results.csv", index=False)
print("Analysis results saved to 'dqn_analysis_results.csv'.")

# Plot results
plt.figure(figsize=(12, 6))
plt.plot(predicted_releases, label="Predicted Releases", color="blue")
plt.plot(actual_releases, label="Actual Releases", linestyle="--", color="orange")
plt.xlabel("Time Step")
plt.ylabel("Releases (af)")
plt.legend()
plt.title("Predicted vs Actual Releases")
plt.grid()
plt.savefig("predicted_vs_actual_releases.png")
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(predicted_storage, label="Predicted Storage", color="green")
plt.plot(actual_storage, label="Actual Storage", linestyle="--", color="red")
plt.xlabel("Time Step")
plt.ylabel("Storage (af)")
plt.legend()
plt.title("Predicted vs Actual Storage")
plt.grid()
plt.savefig("predicted_vs_actual_storage.png")
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(rewards, label="Rewards", color="purple")
plt.xlabel("Time Step")
plt.ylabel("Reward")
plt.title("Rewards Over Time")
plt.grid()
plt.savefig("rewards_over_time.png")
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(q_values, label="Q Values", color="cyan")
plt.xlabel("Time Step")
plt.ylabel("Q Value")
plt.title("Q Values Over Time")
plt.grid()
plt.savefig("q_values_over_time.png")
plt.show()
# Out:
# Analysis results saved to 'dqn_analysis_results.csv'.

# %% [markdown]
# #  Notes-
# To provide even the release value from the data itself for the first time step of every episode
