# %%
# !pip install gymnasium
# !pip install stable-baselines3[extra]
# !pip install tensorboard
# %load_ext tensorboard
# !pip install torch --upgrade --force-reinstall
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)
# Collecting stable-baselines3[extra]
#   Downloading stable_baselines3-2.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (1.26.4)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (2.5.1+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (3.10.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (4.10.0.84)
# Requirement already satisfied: pygame in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (2.18.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (13.9.4)
# Requirement already satisfied: ale-py>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (0.10.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (11.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3[extra]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.70.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (4.25.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (75.1.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3[extra])
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3[extra])
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3[extra])
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable-baselines3[extra])
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable-baselines3[extra])
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable-baselines3[extra])
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable-baselines3[extra])
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable-baselines3[extra])
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable-baselines3[extra])
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3[extra])
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (4.55.6)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3[extra]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3[extra]) (2025.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->stable-baselines3[extra]) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 84.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 61.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 32.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 32.6 MB/s eta 0:00:00
# Downloading stable_baselines3-2.5.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 10.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable-baselines3
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stable-baselines3-2.5.0
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (1.70.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (3.7)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorboard) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (4.25.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (75.1.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Collecting torch
#   Downloading torch-2.6.0-cp311-cp311-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.17.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.10.0 (from torch)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting networkx (from torch)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Downloading jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch)
#   Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.2.0 (from torch)
#   Downloading triton-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Collecting sympy==1.13.1 (from torch)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Downloading torch-2.6.0-cp311-cp311-manylinux1_x86_64.whl (766.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 2.3 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
# Using cached nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
# Using cached nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
# Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# Using cached nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
# Using cached nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
# Using cached nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
# Using cached nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
# Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 5.0 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.1 MB/s eta 0:00:00
# Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 6.4 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 79.1 MB/s eta 0:00:00
# Downloading triton-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (253.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.2/253.2 MB 1.5 MB/s eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading filelock-3.17.0-py3-none-any.whl (16 kB)
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 9.9 MB/s eta 0:00:00
# Downloading jinja2-3.1.5-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.6/134.6 kB 9.2 MB/s eta 0:00:00
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 37.7 MB/s eta 0:00:00
# Downloading MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 21.7 MB/s eta 0:00:00
# Installing collected packages: triton, nvidia-cusparselt-cu12, mpmath, typing-extensions, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, MarkupSafe, fsspec, filelock, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, torch
#   Attempting uninstall: triton
#     Found existing installation: triton 3.1.0
#     Uninstalling triton-3.1.0:
#       Successfully uninstalled triton-3.1.0
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.4.127
#     Uninstalling nvidia-nvjitlink-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.4.127
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.5.147
#     Uninstalling nvidia-curand-cu12-10.3.5.147:
#       Successfully uninstalled nvidia-curand-cu12-10.3.5.147
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.1.3
#     Uninstalling nvidia-cufft-cu12-11.2.1.3:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.1.3
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.4.127
#     Uninstalling nvidia-cuda-runtime-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.4.127
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.4.127
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.4.127
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.4.127
#     Uninstalling nvidia-cuda-cupti-cu12-12.4.127:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.4.127
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.4.5.8
#     Uninstalling nvidia-cublas-cu12-12.4.5.8:
#       Successfully uninstalled nvidia-cublas-cu12-12.4.5.8
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.4.2
#     Uninstalling networkx-3.4.2:
#       Successfully uninstalled networkx-3.4.2
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.17.0
#     Uninstalling filelock-3.17.0:
#       Successfully uninstalled filelock-3.17.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.3.1.170
#     Uninstalling nvidia-cusparse-cu12-12.3.1.170:
#       Successfully uninstalled nvidia-cusparse-cu12-12.3.1.170
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.1.0.70
#     Uninstalling nvidia-cudnn-cu12-9.1.0.70:
#       Successfully uninstalled nvidia-cudnn-cu12-9.1.0.70
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.5
#     Uninstalling Jinja2-3.1.5:
#       Successfully uninstalled Jinja2-3.1.5
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.1.9
#     Uninstalling nvidia-cusolver-cu12-11.6.1.9:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.1.9
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu124
#     Uninstalling torch-2.5.1+cu124:
#       Successfully uninstalled torch-2.5.1+cu124
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.5.1+cu124 requires torch==2.5.1, but you have torch 2.6.0 which is incompatible.
# torchvision 0.20.1+cu124 requires torch==2.5.1, but you have torch 2.6.0 which is incompatible.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.12.0 which is incompatible.
# fastai 2.7.18 requires torch<2.6,>=1.10, but you have torch 2.6.0 which is incompatible.
# Successfully installed MarkupSafe-3.0.2 filelock-3.17.0 fsspec-2024.12.0 jinja2-3.1.5 mpmath-1.3.0 networkx-3.4.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-cusparselt-cu12-0.6.2 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 sympy-1.13.1 torch-2.6.0 triton-3.2.0 typing-extensions-4.12.2

# %% [markdown]
# # **DQN agent with simple binary rewards for storage volume constraints with smaller time steps (threshold) each episode - Agent Based State Propagation - Variation # 1**

# %%
# Import necessary libraries
import os
import numpy as np
import pandas as pd
import torch as th
import gymnasium
from gymnasium import Env
from gymnasium.spaces import Discrete, Box
from stable_baselines3 import DQN
from stable_baselines3.common.callbacks import BaseCallback
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# Define storage and release limits (scaled values will be calculated later)
min_storage_af = 500000
max_storage_af = 1800000
initial_storage_af = 500000
target_storage_af = (min_storage_af + max_storage_af) / 2
release_cfs_discrete = [500, 1000, 1500, 2000, 2500, 3000, 4000]  # More discrete release values
release_af = [r * 1.98211 for r in release_cfs_discrete]  # Convert cfs to acre-feet

# Load and preprocess data
data = pd.read_csv('/content/Clipped_NAVAJORESERVOIR08-18-2024T16.48.23.csv')
storage = data['Storage (af)'].values
evaporation = data['Evaporation (af)'].values
inflow_cfs = data['Inflow** (cfs)'].values
release_cfs = data['Total Release (cfs)'].values
dataset = np.column_stack((storage, evaporation, inflow_cfs * 1.98211, release_cfs * 1.98211))

# Define the custom Reservoir environment
class ReservoirEnv(Env):
    def __init__(self, dataset, release_af, min_storage_af,max_storage_af, episode_length):
        super(ReservoirEnv, self).__init__()
        self.data = dataset
        self.episode_length = episode_length
        self.release_af = release_af
        self.min_storage_af = min_storage_af
        self.max_storage_af = max_storage_af
        self.current_step = 0
        self.episode_step_count = 0
        self.reward_history=[]
        self.episode_reward=[]
        self.storage_history=[]
        self.mean_storage_history = []


        # Define action space and observation space
        self.action_space = Discrete(len(self.release_af))  # Actions: scaled release values
        self.observation_space = Box(low=0, high=1, shape=(3,), dtype=np.float32)

    def reset(self, seed=None):
        self.current_step = np.random.randint(0, len(self.data) - self.episode_length)
        self.episode_step_count = 0
        self.reward_history.clear()

        # Set the storage to the value corresponding to the start of the episode
        self.current_storage = self.data[self.current_step, 0]
        return self._get_observation(), {}

    def _get_observation(self):
        return np.array([self.current_storage, self.data[self.current_step, 1], self.data[self.current_step, 2]])

    def step(self, action):
        # Mapping action index to scaled release value
        release_af_value = self.release_af[action]
        inflow_af = self.data[self.current_step, 2]
        evaporation_af = self.data[self.current_step, 1]

        # Updating storage with inflow, evaporation, and release (all in scaled values)
        self.current_storage += inflow_af - evaporation_af - release_af_value
        # print(f"Step {self.current_step}: Actual Storage: {self.data[self.current_step, 0]}, Current Storage: {self.current_storage}, Actual Release: {self.data[self.current_step, 3]}, Predicted Release: {release_af_value}")

        # Reward calculation (scaled storage range: 0 to 1)
        if self.min_storage_af<= self.current_storage <= self.max_storage_af:
            reward = 1 # Positive reward for staying within bounds
            # reward = 1- (abs(self.current_storage - target_storage_af) / target_storage_af)  # Positive reward for staying within bounds
        else:
            reward = -1  # Negative reward for going out of bounds

        self.reward_history.append(reward)
        self.storage_history.append(self.current_storage)
        self.current_step += 1
        self.episode_step_count += 1
        done = self.current_step >= len(self.data) or (self.episode_step_count % self.episode_length == 0)

        # Recording mean rewards after each episode
        if done:
            cum_reward = sum(self.reward_history)
            self.episode_reward.append(cum_reward)
            self.mean_storage_history.append(np.mean(self.storage_history))

        observation = self._get_observation() if not done else np.zeros(3)
        return observation, reward, done, False, {}

    def render(self, mode='human', close=False):
        pass

# Set up environment
episode_length = 120
env = ReservoirEnv(dataset, release_af, min_storage_af,max_storage_af, episode_length)

# Initialize DQN model
model = DQN(
    "MlpPolicy",
    env,
    verbose=1,
    learning_rate=1e-3,
    batch_size=32,
    train_freq=4,
    buffer_size=100000,
    exploration_fraction=0.3,
    exploration_final_eps=0.01,
    target_update_interval=1000,
)

# Training the model
n_episodes = 20000
total_timesteps = n_episodes * episode_length
model.learn(total_timesteps=total_timesteps)

# Save the model
model.save("dqn_reservoir_agent")

# Plot mean rewards per episode
plt.figure(figsize=(12, 6))
plt.plot(env.episode_reward, label="Cummulative Reward per Episode", color="blue")
plt.xlabel("Episode")
plt.ylabel("Mean Reward")
plt.title("Cummulative Reward per Episode vs Episode Number")
plt.grid()
plt.legend()
plt.savefig("cummulative_rewards_per_episode.png")
plt.show()

# Plot mean storage per episode
plt.figure(figsize=(12, 6))
plt.plot(env.mean_storage_history, label="Mean Storage per Episode", color="blue")
plt.xlabel("Episode")
plt.ylabel("Mean Storage")
plt.title("Mean Storage per Episode vs Episode Number")
plt.grid()
plt.legend()
plt.savefig("mean_storage_per_episode.png")
plt.show()

print("Training complete. Model and reward plot saved.")
# Out:
# Streaming output truncated to the last 5000 lines.
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 6.72     |
# |    n_updates        | 560014   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 117      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18672    |
# |    fps              | 562      |
# |    time_elapsed     | 3982     |
# |    total_timesteps  | 2240640  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.18     |
# |    n_updates        | 560134   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18676    |
# |    fps              | 562      |
# |    time_elapsed     | 3983     |
# |    total_timesteps  | 2241120  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.67     |
# |    n_updates        | 560254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18680    |
# |    fps              | 562      |
# |    time_elapsed     | 3984     |
# |    total_timesteps  | 2241600  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.831    |
# |    n_updates        | 560374   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18684    |
# |    fps              | 562      |
# |    time_elapsed     | 3986     |
# |    total_timesteps  | 2242080  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.34     |
# |    n_updates        | 560494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18688    |
# |    fps              | 562      |
# |    time_elapsed     | 3987     |
# |    total_timesteps  | 2242560  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 8.31     |
# |    n_updates        | 560614   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18692    |
# |    fps              | 562      |
# |    time_elapsed     | 3988     |
# |    total_timesteps  | 2243040  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.22     |
# |    n_updates        | 560734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18696    |
# |    fps              | 562      |
# |    time_elapsed     | 3989     |
# |    total_timesteps  | 2243520  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 7.88     |
# |    n_updates        | 560854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18700    |
# |    fps              | 562      |
# |    time_elapsed     | 3990     |
# |    total_timesteps  | 2244000  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.67     |
# |    n_updates        | 560974   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18704    |
# |    fps              | 562      |
# |    time_elapsed     | 3991     |
# |    total_timesteps  | 2244480  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.07     |
# |    n_updates        | 561094   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18708    |
# |    fps              | 562      |
# |    time_elapsed     | 3992     |
# |    total_timesteps  | 2244960  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.23     |
# |    n_updates        | 561214   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18712    |
# |    fps              | 562      |
# |    time_elapsed     | 3993     |
# |    total_timesteps  | 2245440  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.33     |
# |    n_updates        | 561334   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18716    |
# |    fps              | 562      |
# |    time_elapsed     | 3994     |
# |    total_timesteps  | 2245920  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.99     |
# |    n_updates        | 561454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18720    |
# |    fps              | 562      |
# |    time_elapsed     | 3996     |
# |    total_timesteps  | 2246400  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.46     |
# |    n_updates        | 561574   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18724    |
# |    fps              | 562      |
# |    time_elapsed     | 3997     |
# |    total_timesteps  | 2246880  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.69     |
# |    n_updates        | 561694   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18728    |
# |    fps              | 562      |
# |    time_elapsed     | 3998     |
# |    total_timesteps  | 2247360  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 6.63     |
# |    n_updates        | 561814   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18732    |
# |    fps              | 561      |
# |    time_elapsed     | 4000     |
# |    total_timesteps  | 2247840  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 6.59     |
# |    n_updates        | 561934   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18736    |
# |    fps              | 561      |
# |    time_elapsed     | 4001     |
# |    total_timesteps  | 2248320  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.38     |
# |    n_updates        | 562054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18740    |
# |    fps              | 561      |
# |    time_elapsed     | 4002     |
# |    total_timesteps  | 2248800  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.62     |
# |    n_updates        | 562174   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18744    |
# |    fps              | 561      |
# |    time_elapsed     | 4003     |
# |    total_timesteps  | 2249280  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.78     |
# |    n_updates        | 562294   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18748    |
# |    fps              | 561      |
# |    time_elapsed     | 4004     |
# |    total_timesteps  | 2249760  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.88     |
# |    n_updates        | 562414   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18752    |
# |    fps              | 561      |
# |    time_elapsed     | 4005     |
# |    total_timesteps  | 2250240  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 6.06     |
# |    n_updates        | 562534   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18756    |
# |    fps              | 561      |
# |    time_elapsed     | 4006     |
# |    total_timesteps  | 2250720  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.14     |
# |    n_updates        | 562654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18760    |
# |    fps              | 561      |
# |    time_elapsed     | 4007     |
# |    total_timesteps  | 2251200  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.09     |
# |    n_updates        | 562774   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18764    |
# |    fps              | 561      |
# |    time_elapsed     | 4008     |
# |    total_timesteps  | 2251680  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.88     |
# |    n_updates        | 562894   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18768    |
# |    fps              | 561      |
# |    time_elapsed     | 4009     |
# |    total_timesteps  | 2252160  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.01     |
# |    n_updates        | 563014   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18772    |
# |    fps              | 561      |
# |    time_elapsed     | 4010     |
# |    total_timesteps  | 2252640  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.29     |
# |    n_updates        | 563134   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18776    |
# |    fps              | 561      |
# |    time_elapsed     | 4012     |
# |    total_timesteps  | 2253120  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.77     |
# |    n_updates        | 563254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18780    |
# |    fps              | 561      |
# |    time_elapsed     | 4014     |
# |    total_timesteps  | 2253600  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.782    |
# |    n_updates        | 563374   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18784    |
# |    fps              | 561      |
# |    time_elapsed     | 4015     |
# |    total_timesteps  | 2254080  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.68     |
# |    n_updates        | 563494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18788    |
# |    fps              | 561      |
# |    time_elapsed     | 4016     |
# |    total_timesteps  | 2254560  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.16     |
# |    n_updates        | 563614   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18792    |
# |    fps              | 561      |
# |    time_elapsed     | 4017     |
# |    total_timesteps  | 2255040  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.56     |
# |    n_updates        | 563734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18796    |
# |    fps              | 561      |
# |    time_elapsed     | 4018     |
# |    total_timesteps  | 2255520  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.75     |
# |    n_updates        | 563854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18800    |
# |    fps              | 561      |
# |    time_elapsed     | 4019     |
# |    total_timesteps  | 2256000  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.25     |
# |    n_updates        | 563974   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18804    |
# |    fps              | 561      |
# |    time_elapsed     | 4020     |
# |    total_timesteps  | 2256480  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.13     |
# |    n_updates        | 564094   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18808    |
# |    fps              | 561      |
# |    time_elapsed     | 4021     |
# |    total_timesteps  | 2256960  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.954    |
# |    n_updates        | 564214   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18812    |
# |    fps              | 561      |
# |    time_elapsed     | 4022     |
# |    total_timesteps  | 2257440  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 15.5     |
# |    n_updates        | 564334   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18816    |
# |    fps              | 561      |
# |    time_elapsed     | 4023     |
# |    total_timesteps  | 2257920  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.28     |
# |    n_updates        | 564454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18820    |
# |    fps              | 561      |
# |    time_elapsed     | 4024     |
# |    total_timesteps  | 2258400  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.88     |
# |    n_updates        | 564574   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18824    |
# |    fps              | 561      |
# |    time_elapsed     | 4026     |
# |    total_timesteps  | 2258880  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.15     |
# |    n_updates        | 564694   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18828    |
# |    fps              | 560      |
# |    time_elapsed     | 4027     |
# |    total_timesteps  | 2259360  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.97     |
# |    n_updates        | 564814   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18832    |
# |    fps              | 560      |
# |    time_elapsed     | 4029     |
# |    total_timesteps  | 2259840  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.29     |
# |    n_updates        | 564934   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18836    |
# |    fps              | 560      |
# |    time_elapsed     | 4030     |
# |    total_timesteps  | 2260320  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.743    |
# |    n_updates        | 565054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18840    |
# |    fps              | 560      |
# |    time_elapsed     | 4031     |
# |    total_timesteps  | 2260800  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.22     |
# |    n_updates        | 565174   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18844    |
# |    fps              | 560      |
# |    time_elapsed     | 4032     |
# |    total_timesteps  | 2261280  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.98     |
# |    n_updates        | 565294   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18848    |
# |    fps              | 560      |
# |    time_elapsed     | 4033     |
# |    total_timesteps  | 2261760  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.42     |
# |    n_updates        | 565414   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18852    |
# |    fps              | 560      |
# |    time_elapsed     | 4034     |
# |    total_timesteps  | 2262240  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.43     |
# |    n_updates        | 565534   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18856    |
# |    fps              | 560      |
# |    time_elapsed     | 4035     |
# |    total_timesteps  | 2262720  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.97     |
# |    n_updates        | 565654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18860    |
# |    fps              | 560      |
# |    time_elapsed     | 4036     |
# |    total_timesteps  | 2263200  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 14.6     |
# |    n_updates        | 565774   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18864    |
# |    fps              | 560      |
# |    time_elapsed     | 4037     |
# |    total_timesteps  | 2263680  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.01     |
# |    n_updates        | 565894   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18868    |
# |    fps              | 560      |
# |    time_elapsed     | 4038     |
# |    total_timesteps  | 2264160  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.4      |
# |    n_updates        | 566014   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18872    |
# |    fps              | 560      |
# |    time_elapsed     | 4040     |
# |    total_timesteps  | 2264640  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 10.8     |
# |    n_updates        | 566134   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 117      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18876    |
# |    fps              | 560      |
# |    time_elapsed     | 4041     |
# |    total_timesteps  | 2265120  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.81     |
# |    n_updates        | 566254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18880    |
# |    fps              | 560      |
# |    time_elapsed     | 4043     |
# |    total_timesteps  | 2265600  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.66     |
# |    n_updates        | 566374   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18884    |
# |    fps              | 560      |
# |    time_elapsed     | 4044     |
# |    total_timesteps  | 2266080  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.689    |
# |    n_updates        | 566494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18888    |
# |    fps              | 560      |
# |    time_elapsed     | 4045     |
# |    total_timesteps  | 2266560  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.57     |
# |    n_updates        | 566614   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18892    |
# |    fps              | 560      |
# |    time_elapsed     | 4046     |
# |    total_timesteps  | 2267040  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.14     |
# |    n_updates        | 566734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18896    |
# |    fps              | 560      |
# |    time_elapsed     | 4047     |
# |    total_timesteps  | 2267520  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.76     |
# |    n_updates        | 566854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18900    |
# |    fps              | 560      |
# |    time_elapsed     | 4048     |
# |    total_timesteps  | 2268000  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 11.2     |
# |    n_updates        | 566974   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18904    |
# |    fps              | 560      |
# |    time_elapsed     | 4049     |
# |    total_timesteps  | 2268480  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.35     |
# |    n_updates        | 567094   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18908    |
# |    fps              | 560      |
# |    time_elapsed     | 4050     |
# |    total_timesteps  | 2268960  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.66     |
# |    n_updates        | 567214   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18912    |
# |    fps              | 560      |
# |    time_elapsed     | 4051     |
# |    total_timesteps  | 2269440  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.73     |
# |    n_updates        | 567334   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18916    |
# |    fps              | 560      |
# |    time_elapsed     | 4052     |
# |    total_timesteps  | 2269920  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.07     |
# |    n_updates        | 567454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18920    |
# |    fps              | 560      |
# |    time_elapsed     | 4053     |
# |    total_timesteps  | 2270400  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.43     |
# |    n_updates        | 567574   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18924    |
# |    fps              | 559      |
# |    time_elapsed     | 4055     |
# |    total_timesteps  | 2270880  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.76     |
# |    n_updates        | 567694   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18928    |
# |    fps              | 559      |
# |    time_elapsed     | 4056     |
# |    total_timesteps  | 2271360  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 10.3     |
# |    n_updates        | 567814   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18932    |
# |    fps              | 559      |
# |    time_elapsed     | 4057     |
# |    total_timesteps  | 2271840  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.33     |
# |    n_updates        | 567934   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18936    |
# |    fps              | 559      |
# |    time_elapsed     | 4058     |
# |    total_timesteps  | 2272320  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.23     |
# |    n_updates        | 568054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18940    |
# |    fps              | 559      |
# |    time_elapsed     | 4059     |
# |    total_timesteps  | 2272800  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.14     |
# |    n_updates        | 568174   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18944    |
# |    fps              | 559      |
# |    time_elapsed     | 4060     |
# |    total_timesteps  | 2273280  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 6.87     |
# |    n_updates        | 568294   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18948    |
# |    fps              | 559      |
# |    time_elapsed     | 4061     |
# |    total_timesteps  | 2273760  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.72     |
# |    n_updates        | 568414   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18952    |
# |    fps              | 559      |
# |    time_elapsed     | 4063     |
# |    total_timesteps  | 2274240  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.44     |
# |    n_updates        | 568534   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18956    |
# |    fps              | 559      |
# |    time_elapsed     | 4064     |
# |    total_timesteps  | 2274720  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.998    |
# |    n_updates        | 568654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18960    |
# |    fps              | 559      |
# |    time_elapsed     | 4065     |
# |    total_timesteps  | 2275200  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.632    |
# |    n_updates        | 568774   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18964    |
# |    fps              | 559      |
# |    time_elapsed     | 4066     |
# |    total_timesteps  | 2275680  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.975    |
# |    n_updates        | 568894   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18968    |
# |    fps              | 559      |
# |    time_elapsed     | 4067     |
# |    total_timesteps  | 2276160  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.75     |
# |    n_updates        | 569014   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 112      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18972    |
# |    fps              | 559      |
# |    time_elapsed     | 4069     |
# |    total_timesteps  | 2276640  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.93     |
# |    n_updates        | 569134   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 112      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18976    |
# |    fps              | 559      |
# |    time_elapsed     | 4070     |
# |    total_timesteps  | 2277120  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.03     |
# |    n_updates        | 569254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 112      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18980    |
# |    fps              | 559      |
# |    time_elapsed     | 4071     |
# |    total_timesteps  | 2277600  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.83     |
# |    n_updates        | 569374   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 112      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18984    |
# |    fps              | 559      |
# |    time_elapsed     | 4072     |
# |    total_timesteps  | 2278080  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 10.4     |
# |    n_updates        | 569494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 112      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18988    |
# |    fps              | 559      |
# |    time_elapsed     | 4073     |
# |    total_timesteps  | 2278560  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.32     |
# |    n_updates        | 569614   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 112      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18992    |
# |    fps              | 559      |
# |    time_elapsed     | 4074     |
# |    total_timesteps  | 2279040  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.781    |
# |    n_updates        | 569734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18996    |
# |    fps              | 559      |
# |    time_elapsed     | 4075     |
# |    total_timesteps  | 2279520  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.92     |
# |    n_updates        | 569854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19000    |
# |    fps              | 559      |
# |    time_elapsed     | 4077     |
# |    total_timesteps  | 2280000  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.28     |
# |    n_updates        | 569974   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19004    |
# |    fps              | 559      |
# |    time_elapsed     | 4078     |
# |    total_timesteps  | 2280480  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.44     |
# |    n_updates        | 570094   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19008    |
# |    fps              | 559      |
# |    time_elapsed     | 4079     |
# |    total_timesteps  | 2280960  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 10       |
# |    n_updates        | 570214   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19012    |
# |    fps              | 559      |
# |    time_elapsed     | 4080     |
# |    total_timesteps  | 2281440  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.99     |
# |    n_updates        | 570334   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19016    |
# |    fps              | 559      |
# |    time_elapsed     | 4081     |
# |    total_timesteps  | 2281920  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.38     |
# |    n_updates        | 570454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 109      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19020    |
# |    fps              | 558      |
# |    time_elapsed     | 4083     |
# |    total_timesteps  | 2282400  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 6.44     |
# |    n_updates        | 570574   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19024    |
# |    fps              | 558      |
# |    time_elapsed     | 4084     |
# |    total_timesteps  | 2282880  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.81     |
# |    n_updates        | 570694   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19028    |
# |    fps              | 558      |
# |    time_elapsed     | 4085     |
# |    total_timesteps  | 2283360  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 6.04     |
# |    n_updates        | 570814   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19032    |
# |    fps              | 558      |
# |    time_elapsed     | 4086     |
# |    total_timesteps  | 2283840  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 8.99     |
# |    n_updates        | 570934   |
# ...
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.39     |
# |    n_updates        | 596374   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 117      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19884    |
# |    fps              | 550      |
# |    time_elapsed     | 4336     |
# |    total_timesteps  | 2386080  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.28     |
# |    n_updates        | 596494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 117      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19888    |
# |    fps              | 550      |
# |    time_elapsed     | 4337     |
# |    total_timesteps  | 2386560  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.65     |
# |    n_updates        | 596614   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 117      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19892    |
# |    fps              | 550      |
# |    time_elapsed     | 4338     |
# |    total_timesteps  | 2387040  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.12     |
# |    n_updates        | 596734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19896    |
# |    fps              | 550      |
# |    time_elapsed     | 4339     |
# |    total_timesteps  | 2387520  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.01     |
# |    n_updates        | 596854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19900    |
# |    fps              | 550      |
# |    time_elapsed     | 4340     |
# |    total_timesteps  | 2388000  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.55     |
# |    n_updates        | 596974   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19904    |
# |    fps              | 550      |
# |    time_elapsed     | 4342     |
# |    total_timesteps  | 2388480  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.18     |
# |    n_updates        | 597094   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19908    |
# |    fps              | 549      |
# |    time_elapsed     | 4344     |
# |    total_timesteps  | 2388960  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.56     |
# |    n_updates        | 597214   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19912    |
# |    fps              | 549      |
# |    time_elapsed     | 4345     |
# |    total_timesteps  | 2389440  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.602    |
# |    n_updates        | 597334   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19916    |
# |    fps              | 549      |
# |    time_elapsed     | 4346     |
# |    total_timesteps  | 2389920  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.08     |
# |    n_updates        | 597454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19920    |
# |    fps              | 549      |
# |    time_elapsed     | 4347     |
# |    total_timesteps  | 2390400  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.99     |
# |    n_updates        | 597574   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19924    |
# |    fps              | 549      |
# |    time_elapsed     | 4348     |
# |    total_timesteps  | 2390880  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.65     |
# |    n_updates        | 597694   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19928    |
# |    fps              | 549      |
# |    time_elapsed     | 4349     |
# |    total_timesteps  | 2391360  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.359    |
# |    n_updates        | 597814   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19932    |
# |    fps              | 549      |
# |    time_elapsed     | 4350     |
# |    total_timesteps  | 2391840  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.04     |
# |    n_updates        | 597934   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19936    |
# |    fps              | 549      |
# |    time_elapsed     | 4351     |
# |    total_timesteps  | 2392320  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.33     |
# |    n_updates        | 598054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19940    |
# |    fps              | 549      |
# |    time_elapsed     | 4353     |
# |    total_timesteps  | 2392800  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.17     |
# |    n_updates        | 598174   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19944    |
# |    fps              | 549      |
# |    time_elapsed     | 4354     |
# |    total_timesteps  | 2393280  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.48     |
# |    n_updates        | 598294   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19948    |
# |    fps              | 549      |
# |    time_elapsed     | 4355     |
# |    total_timesteps  | 2393760  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.93     |
# |    n_updates        | 598414   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19952    |
# |    fps              | 549      |
# |    time_elapsed     | 4356     |
# |    total_timesteps  | 2394240  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.44     |
# |    n_updates        | 598534   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19956    |
# |    fps              | 549      |
# |    time_elapsed     | 4358     |
# |    total_timesteps  | 2394720  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.29     |
# |    n_updates        | 598654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19960    |
# |    fps              | 549      |
# |    time_elapsed     | 4359     |
# |    total_timesteps  | 2395200  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.729    |
# |    n_updates        | 598774   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19964    |
# |    fps              | 549      |
# |    time_elapsed     | 4360     |
# |    total_timesteps  | 2395680  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.12     |
# |    n_updates        | 598894   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19968    |
# |    fps              | 549      |
# |    time_elapsed     | 4361     |
# |    total_timesteps  | 2396160  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.34     |
# |    n_updates        | 599014   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19972    |
# |    fps              | 549      |
# |    time_elapsed     | 4362     |
# |    total_timesteps  | 2396640  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.32     |
# |    n_updates        | 599134   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19976    |
# |    fps              | 549      |
# |    time_elapsed     | 4364     |
# |    total_timesteps  | 2397120  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2        |
# |    n_updates        | 599254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19980    |
# |    fps              | 549      |
# |    time_elapsed     | 4365     |
# |    total_timesteps  | 2397600  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.76     |
# |    n_updates        | 599374   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19984    |
# |    fps              | 549      |
# |    time_elapsed     | 4366     |
# |    total_timesteps  | 2398080  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.787    |
# |    n_updates        | 599494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19988    |
# |    fps              | 549      |
# |    time_elapsed     | 4367     |
# |    total_timesteps  | 2398560  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.68     |
# |    n_updates        | 599614   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19992    |
# |    fps              | 549      |
# |    time_elapsed     | 4368     |
# |    total_timesteps  | 2399040  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 9.79     |
# |    n_updates        | 599734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19996    |
# |    fps              | 549      |
# |    time_elapsed     | 4369     |
# |    total_timesteps  | 2399520  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.83     |
# |    n_updates        | 599854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 20000    |
# |    fps              | 549      |
# |    time_elapsed     | 4371     |
# |    total_timesteps  | 2400000  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.911    |
# |    n_updates        | 599974   |
# ----------------------------------
# Training complete. Model and reward plot saved.

# %%
# Load the trained DQN agent
model = DQN.load("dqn_reservoir_agent")

# Set up variables for predictions
predicted_storage = []
actual_storage = []
predicted_release = []
actual_release = []

# Initialize current storage
current_storage = dataset[0,0]
print(current_storage)

# Perform predictions
for i in range(len(dataset)):
    # Get the observation from the dataset (without scaling)
    observation = np.array([current_storage, dataset[i, 1], dataset[i, 2]])
    # Predict the action using the trained agent
    action, _ = model.predict(observation)

    # Map the action to the corresponding release value in acre-feet
    predicted_release_af = release_af[action]

    # Extract inflow and evaporation directly from the dataset (unscaled)
    inflow_af = dataset[i, 2]
    evaporation_af = dataset[i, 1]

    # Update the current storage using the predicted release, inflow, and evaporation
    current_storage += inflow_af - evaporation_af - predicted_release_af

    # Store results for analysis
    predicted_storage.append(current_storage)
    predicted_release.append(predicted_release_af)
    actual_storage.append(dataset[i, 0])  # Actual storage from the dataset
    actual_release.append(dataset[i, 3])  # Actual release from the dataset
    # print(f"Step {i}: Observation: {observation}, Predicted Release: {predicted_release_af}, Current Storage: {current_storage}")


# Save results to CSV files
predicted_vs_actual_storage = pd.DataFrame({
    "Predicted Storage (af)": predicted_storage,
    "Actual Storage (af)": actual_storage
})
predicted_vs_actual_release = pd.DataFrame({
    "Predicted Release (af)": predicted_release,
    "Actual Release (af)": actual_release
})

# Save the results to CSV files
predicted_vs_actual_storage.to_csv("predicted_vs_actual_storage_complete_data.csv", index=False)
predicted_vs_actual_release.to_csv("predicted_vs_actual_release_complete_data.csv", index=False)
pd.DataFrame(dataset).to_csv("complete_dataset.csv", index=False)

print("Prediction completed and saved to CSV files.")

# Plot Predicted vs Actual Storage
plt.figure(figsize=(12, 6))
plt.plot(actual_storage, label="Actual Storage (af)", color="blue")
plt.plot(predicted_storage, label="Predicted Storage (af)", color="orange")
plt.xlabel("Timestep")
plt.ylabel("Storage (af)")
plt.title("Predicted vs Actual Storage")
plt.legend()
plt.grid()
plt.show()

# Plot Predicted vs Actual Release
plt.figure(figsize=(12, 6))
plt.plot(actual_release, label="Actual Release (af)", color="blue")
plt.plot(predicted_release, label="Predicted Release (af)", color="orange")
plt.xlabel("Timestep")
plt.ylabel("Release (af)")
plt.title("Predicted vs Actual Release")
plt.legend()
plt.grid()
plt.show()
# Out:
# 506159.0
# Prediction completed and saved to CSV files.

# %% [markdown]
# # **DQN agent with simple binary rewards for storage volume constraints with smaller time steps (threshold) each episode - Agent Based State Propagation - Variation # 2**

# %%
# Import necessary libraries
import os
import numpy as np
import pandas as pd
import torch as th
import gymnasium
from gymnasium import Env
from gymnasium.spaces import Discrete, Box
from stable_baselines3 import DQN
from stable_baselines3.common.callbacks import BaseCallback
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# Define storage and release limits (scaled values will be calculated later)
min_storage_af = 500000
max_storage_af = 1800000
initial_storage_af = 500000
target_storage_af = (min_storage_af + max_storage_af) / 2
release_cfs_discrete = [500, 1000, 1500, 2000, 2500, 3000, 3500, 4000]  # More discrete release values
release_af = [r * 1.98211 for r in release_cfs_discrete]  # Convert cfs to acre-feet

# Load and preprocess data
data = pd.read_csv('/content/Clipped_NAVAJORESERVOIR08-18-2024T16.48.23.csv')
storage = data['Storage (af)'].values
evaporation = data['Evaporation (af)'].values
inflow_cfs = data['Inflow** (cfs)'].values
release_cfs = data['Total Release (cfs)'].values
dataset = np.column_stack((storage, evaporation, inflow_cfs * 1.98211, release_cfs * 1.98211))

# Define the custom Reservoir environment
class ReservoirEnv(Env):
    def __init__(self, dataset, release_af, min_storage_af,max_storage_af, episode_length):
        super(ReservoirEnv, self).__init__()
        self.data = dataset
        self.episode_length = episode_length
        self.release_af = release_af
        self.min_storage_af = min_storage_af
        self.max_storage_af = max_storage_af
        self.current_step = 0
        self.episode_step_count = 0
        self.reward_history=[]
        self.episode_reward=[]
        self.storage_history=[]
        self.mean_storage_history = []


        # Define action space and observation space
        self.action_space = Discrete(len(self.release_af))  # Actions: scaled release values
        self.observation_space = Box(low=0, high=1, shape=(3,), dtype=np.float32)

    def reset(self, seed=None):
        self.current_step = np.random.randint(0, len(self.data) - self.episode_length)
        self.episode_step_count = 0
        self.reward_history.clear()

        # Set the storage to the value corresponding to the start of the episode
        self.current_storage = self.data[self.current_step, 0]
        return self._get_observation(), {}

    def _get_observation(self):
        return np.array([self.current_storage, self.data[self.current_step, 1], self.data[self.current_step, 2]])

    def step(self, action):
        # Mapping action index to scaled release value
        release_af_value = self.release_af[action]
        inflow_af = self.data[self.current_step, 2]
        evaporation_af = self.data[self.current_step, 1]

        # Updating storage with inflow, evaporation, and release (all in scaled values)
        self.current_storage += inflow_af - evaporation_af - release_af_value
        # print(f"Step {self.current_step}: Actual Storage: {self.data[self.current_step, 0]}, Current Storage: {self.current_storage}, Actual Release: {self.data[self.current_step, 3]}, Predicted Release: {release_af_value}")

        # Reward calculation (scaled storage range: 0 to 1)
        if self.min_storage_af<= self.current_storage <= self.max_storage_af:
            reward = 1 # Positive reward for staying within bounds
            # reward = 1- (abs(self.current_storage - target_storage_af) / target_storage_af)  # Positive reward for staying within bounds
        else:
            reward = -1  # Negative reward for going out of bounds

        self.reward_history.append(reward)
        self.storage_history.append(self.current_storage)
        self.current_step += 1
        self.episode_step_count += 1
        done = self.current_step >= len(self.data) or (self.episode_step_count % self.episode_length == 0)

        # Recording mean rewards after each episode
        if done:
            cum_reward = sum(self.reward_history)
            self.episode_reward.append(cum_reward)
            self.mean_storage_history.append(np.mean(self.storage_history))

        observation = self._get_observation() if not done else np.zeros(3)
        return observation, reward, done, False, {}

    def render(self, mode='human', close=False):
        pass

# Set up environment
episode_length = 120
env = ReservoirEnv(dataset, release_af, min_storage_af,max_storage_af, episode_length)

# Initialize DQN model
model = DQN(
    "MlpPolicy",
    env,
    verbose=1,
    learning_rate=1e-4,
    batch_size=32,
    train_freq=4,
    buffer_size=100000,
    exploration_fraction=0.3,
    exploration_final_eps=0.01,
    target_update_interval=1000,
)

# Training the model
n_episodes = 20000
total_timesteps = n_episodes * episode_length
model.learn(total_timesteps=total_timesteps)

# Save the model
model.save("dqn_reservoir_agent")

# Plot mean rewards per episode
plt.figure(figsize=(12, 6))
plt.plot(env.episode_reward, label="Cummulative Reward per Episode", color="blue")
plt.xlabel("Episode")
plt.ylabel("Mean Reward")
plt.title("Cummulative Reward per Episode vs Episode Number")
plt.grid()
plt.legend()
plt.savefig("cummulative_rewards_per_episode.png")
plt.show()

# Plot mean storage per episode
plt.figure(figsize=(12, 6))
plt.plot(env.mean_storage_history, label="Mean Storage per Episode", color="blue")
plt.xlabel("Episode")
plt.ylabel("Mean Storage")
plt.title("Mean Storage per Episode vs Episode Number")
plt.grid()
plt.legend()
plt.savefig("mean_storage_per_episode.png")
plt.show()

pd.DataFrame(env.episode_reward).to_csv("cummulative_reward_per_episode.csv", index=False)
print("Training complete. Model and reward plot saved.")
# Out:
# Streaming output truncated to the last 5000 lines.
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.69     |
# |    n_updates        | 560014   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18672    |
# |    fps              | 515      |
# |    time_elapsed     | 4345     |
# |    total_timesteps  | 2240640  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.26     |
# |    n_updates        | 560134   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18676    |
# |    fps              | 515      |
# |    time_elapsed     | 4346     |
# |    total_timesteps  | 2241120  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.81     |
# |    n_updates        | 560254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18680    |
# |    fps              | 515      |
# |    time_elapsed     | 4347     |
# |    total_timesteps  | 2241600  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.957    |
# |    n_updates        | 560374   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18684    |
# |    fps              | 515      |
# |    time_elapsed     | 4348     |
# |    total_timesteps  | 2242080  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.21     |
# |    n_updates        | 560494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18688    |
# |    fps              | 515      |
# |    time_elapsed     | 4349     |
# |    total_timesteps  | 2242560  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.77     |
# |    n_updates        | 560614   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18692    |
# |    fps              | 515      |
# |    time_elapsed     | 4350     |
# |    total_timesteps  | 2243040  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.88     |
# |    n_updates        | 560734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18696    |
# |    fps              | 515      |
# |    time_elapsed     | 4351     |
# |    total_timesteps  | 2243520  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.62     |
# |    n_updates        | 560854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18700    |
# |    fps              | 515      |
# |    time_elapsed     | 4353     |
# |    total_timesteps  | 2244000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 12.1     |
# |    n_updates        | 560974   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18704    |
# |    fps              | 515      |
# |    time_elapsed     | 4354     |
# |    total_timesteps  | 2244480  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.18     |
# |    n_updates        | 561094   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18708    |
# |    fps              | 515      |
# |    time_elapsed     | 4356     |
# |    total_timesteps  | 2244960  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 11.7     |
# |    n_updates        | 561214   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18712    |
# |    fps              | 515      |
# |    time_elapsed     | 4358     |
# |    total_timesteps  | 2245440  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.58     |
# |    n_updates        | 561334   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18716    |
# |    fps              | 515      |
# |    time_elapsed     | 4359     |
# |    total_timesteps  | 2245920  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.64     |
# |    n_updates        | 561454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18720    |
# |    fps              | 515      |
# |    time_elapsed     | 4360     |
# |    total_timesteps  | 2246400  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.84     |
# |    n_updates        | 561574   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18724    |
# |    fps              | 515      |
# |    time_elapsed     | 4361     |
# |    total_timesteps  | 2246880  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 11.1     |
# |    n_updates        | 561694   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18728    |
# |    fps              | 515      |
# |    time_elapsed     | 4362     |
# |    total_timesteps  | 2247360  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.93     |
# |    n_updates        | 561814   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18732    |
# |    fps              | 515      |
# |    time_elapsed     | 4363     |
# |    total_timesteps  | 2247840  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.5      |
# |    n_updates        | 561934   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18736    |
# |    fps              | 515      |
# |    time_elapsed     | 4364     |
# |    total_timesteps  | 2248320  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.72     |
# |    n_updates        | 562054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18740    |
# |    fps              | 515      |
# |    time_elapsed     | 4366     |
# |    total_timesteps  | 2248800  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.06     |
# |    n_updates        | 562174   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18744    |
# |    fps              | 515      |
# |    time_elapsed     | 4367     |
# |    total_timesteps  | 2249280  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.13     |
# |    n_updates        | 562294   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18748    |
# |    fps              | 514      |
# |    time_elapsed     | 4368     |
# |    total_timesteps  | 2249760  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.41     |
# |    n_updates        | 562414   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18752    |
# |    fps              | 514      |
# |    time_elapsed     | 4370     |
# |    total_timesteps  | 2250240  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15     |
# |    n_updates        | 562534   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18756    |
# |    fps              | 514      |
# |    time_elapsed     | 4372     |
# |    total_timesteps  | 2250720  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.46     |
# |    n_updates        | 562654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18760    |
# |    fps              | 514      |
# |    time_elapsed     | 4373     |
# |    total_timesteps  | 2251200  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.27     |
# |    n_updates        | 562774   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18764    |
# |    fps              | 514      |
# |    time_elapsed     | 4374     |
# |    total_timesteps  | 2251680  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 11.1     |
# |    n_updates        | 562894   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18768    |
# |    fps              | 514      |
# |    time_elapsed     | 4375     |
# |    total_timesteps  | 2252160  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.33     |
# |    n_updates        | 563014   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18772    |
# |    fps              | 514      |
# |    time_elapsed     | 4376     |
# |    total_timesteps  | 2252640  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.61     |
# |    n_updates        | 563134   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18776    |
# |    fps              | 514      |
# |    time_elapsed     | 4377     |
# |    total_timesteps  | 2253120  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.36     |
# |    n_updates        | 563254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18780    |
# |    fps              | 514      |
# |    time_elapsed     | 4378     |
# |    total_timesteps  | 2253600  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.27     |
# |    n_updates        | 563374   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18784    |
# |    fps              | 514      |
# |    time_elapsed     | 4380     |
# |    total_timesteps  | 2254080  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.45     |
# |    n_updates        | 563494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18788    |
# |    fps              | 514      |
# |    time_elapsed     | 4381     |
# |    total_timesteps  | 2254560  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.06     |
# |    n_updates        | 563614   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18792    |
# |    fps              | 514      |
# |    time_elapsed     | 4382     |
# |    total_timesteps  | 2255040  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.609    |
# |    n_updates        | 563734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18796    |
# |    fps              | 514      |
# |    time_elapsed     | 4384     |
# |    total_timesteps  | 2255520  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.44     |
# |    n_updates        | 563854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 117      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18800    |
# |    fps              | 514      |
# |    time_elapsed     | 4386     |
# |    total_timesteps  | 2256000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 13.3     |
# |    n_updates        | 563974   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18804    |
# |    fps              | 514      |
# |    time_elapsed     | 4387     |
# |    total_timesteps  | 2256480  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.31     |
# |    n_updates        | 564094   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18808    |
# |    fps              | 514      |
# |    time_elapsed     | 4388     |
# |    total_timesteps  | 2256960  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.18     |
# |    n_updates        | 564214   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18812    |
# |    fps              | 514      |
# |    time_elapsed     | 4389     |
# |    total_timesteps  | 2257440  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.76     |
# |    n_updates        | 564334   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18816    |
# |    fps              | 514      |
# |    time_elapsed     | 4390     |
# |    total_timesteps  | 2257920  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.34     |
# |    n_updates        | 564454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18820    |
# |    fps              | 514      |
# |    time_elapsed     | 4391     |
# |    total_timesteps  | 2258400  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.42     |
# |    n_updates        | 564574   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18824    |
# |    fps              | 514      |
# |    time_elapsed     | 4392     |
# |    total_timesteps  | 2258880  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.11     |
# |    n_updates        | 564694   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18828    |
# |    fps              | 514      |
# |    time_elapsed     | 4393     |
# |    total_timesteps  | 2259360  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.02     |
# |    n_updates        | 564814   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18832    |
# |    fps              | 514      |
# |    time_elapsed     | 4395     |
# |    total_timesteps  | 2259840  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.91     |
# |    n_updates        | 564934   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18836    |
# |    fps              | 514      |
# |    time_elapsed     | 4396     |
# |    total_timesteps  | 2260320  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.77     |
# |    n_updates        | 565054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18840    |
# |    fps              | 514      |
# |    time_elapsed     | 4398     |
# |    total_timesteps  | 2260800  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.786    |
# |    n_updates        | 565174   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18844    |
# |    fps              | 513      |
# |    time_elapsed     | 4400     |
# |    total_timesteps  | 2261280  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.44     |
# |    n_updates        | 565294   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18848    |
# |    fps              | 513      |
# |    time_elapsed     | 4401     |
# |    total_timesteps  | 2261760  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.77     |
# |    n_updates        | 565414   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18852    |
# |    fps              | 513      |
# |    time_elapsed     | 4402     |
# |    total_timesteps  | 2262240  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.97     |
# |    n_updates        | 565534   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18856    |
# |    fps              | 513      |
# |    time_elapsed     | 4403     |
# |    total_timesteps  | 2262720  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.3      |
# |    n_updates        | 565654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18860    |
# |    fps              | 513      |
# |    time_elapsed     | 4404     |
# |    total_timesteps  | 2263200  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.6      |
# |    n_updates        | 565774   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18864    |
# |    fps              | 513      |
# |    time_elapsed     | 4405     |
# |    total_timesteps  | 2263680  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.24     |
# |    n_updates        | 565894   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18868    |
# |    fps              | 513      |
# |    time_elapsed     | 4407     |
# |    total_timesteps  | 2264160  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15     |
# |    n_updates        | 566014   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18872    |
# |    fps              | 513      |
# |    time_elapsed     | 4408     |
# |    total_timesteps  | 2264640  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.805    |
# |    n_updates        | 566134   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18876    |
# |    fps              | 513      |
# |    time_elapsed     | 4409     |
# |    total_timesteps  | 2265120  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.927    |
# |    n_updates        | 566254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18880    |
# |    fps              | 513      |
# |    time_elapsed     | 4410     |
# |    total_timesteps  | 2265600  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.56     |
# |    n_updates        | 566374   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18884    |
# |    fps              | 513      |
# |    time_elapsed     | 4412     |
# |    total_timesteps  | 2266080  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.9      |
# |    n_updates        | 566494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18888    |
# |    fps              | 513      |
# |    time_elapsed     | 4413     |
# |    total_timesteps  | 2266560  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.12     |
# |    n_updates        | 566614   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18892    |
# |    fps              | 513      |
# |    time_elapsed     | 4415     |
# |    total_timesteps  | 2267040  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.71     |
# |    n_updates        | 566734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18896    |
# |    fps              | 513      |
# |    time_elapsed     | 4416     |
# |    total_timesteps  | 2267520  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.45     |
# |    n_updates        | 566854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18900    |
# |    fps              | 513      |
# |    time_elapsed     | 4418     |
# |    total_timesteps  | 2268000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.13     |
# |    n_updates        | 566974   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18904    |
# |    fps              | 513      |
# |    time_elapsed     | 4420     |
# |    total_timesteps  | 2268480  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.18     |
# |    n_updates        | 567094   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18908    |
# |    fps              | 513      |
# |    time_elapsed     | 4421     |
# |    total_timesteps  | 2268960  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.906    |
# |    n_updates        | 567214   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18912    |
# |    fps              | 513      |
# |    time_elapsed     | 4423     |
# |    total_timesteps  | 2269440  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.78     |
# |    n_updates        | 567334   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18916    |
# |    fps              | 513      |
# |    time_elapsed     | 4424     |
# |    total_timesteps  | 2269920  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.01     |
# |    n_updates        | 567454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18920    |
# |    fps              | 513      |
# |    time_elapsed     | 4425     |
# |    total_timesteps  | 2270400  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.71     |
# |    n_updates        | 567574   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18924    |
# |    fps              | 512      |
# |    time_elapsed     | 4427     |
# |    total_timesteps  | 2270880  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.14     |
# |    n_updates        | 567694   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18928    |
# |    fps              | 512      |
# |    time_elapsed     | 4429     |
# |    total_timesteps  | 2271360  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.631    |
# |    n_updates        | 567814   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18932    |
# |    fps              | 512      |
# |    time_elapsed     | 4430     |
# |    total_timesteps  | 2271840  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.21     |
# |    n_updates        | 567934   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18936    |
# |    fps              | 512      |
# |    time_elapsed     | 4431     |
# |    total_timesteps  | 2272320  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.51     |
# |    n_updates        | 568054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18940    |
# |    fps              | 512      |
# |    time_elapsed     | 4432     |
# |    total_timesteps  | 2272800  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.66     |
# |    n_updates        | 568174   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18944    |
# |    fps              | 512      |
# |    time_elapsed     | 4433     |
# |    total_timesteps  | 2273280  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.39     |
# |    n_updates        | 568294   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18948    |
# |    fps              | 512      |
# |    time_elapsed     | 4434     |
# |    total_timesteps  | 2273760  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.71     |
# |    n_updates        | 568414   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18952    |
# |    fps              | 512      |
# |    time_elapsed     | 4435     |
# |    total_timesteps  | 2274240  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.4      |
# |    n_updates        | 568534   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18956    |
# |    fps              | 512      |
# |    time_elapsed     | 4437     |
# |    total_timesteps  | 2274720  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.69     |
# |    n_updates        | 568654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18960    |
# |    fps              | 512      |
# |    time_elapsed     | 4438     |
# |    total_timesteps  | 2275200  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.11     |
# |    n_updates        | 568774   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18964    |
# |    fps              | 512      |
# |    time_elapsed     | 4439     |
# |    total_timesteps  | 2275680  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 10.3     |
# |    n_updates        | 568894   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18968    |
# |    fps              | 512      |
# |    time_elapsed     | 4441     |
# |    total_timesteps  | 2276160  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.02     |
# |    n_updates        | 569014   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18972    |
# |    fps              | 512      |
# |    time_elapsed     | 4443     |
# |    total_timesteps  | 2276640  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.11     |
# |    n_updates        | 569134   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18976    |
# |    fps              | 512      |
# |    time_elapsed     | 4444     |
# |    total_timesteps  | 2277120  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.96     |
# |    n_updates        | 569254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18980    |
# |    fps              | 512      |
# |    time_elapsed     | 4445     |
# |    total_timesteps  | 2277600  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.86     |
# |    n_updates        | 569374   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18984    |
# |    fps              | 512      |
# |    time_elapsed     | 4446     |
# |    total_timesteps  | 2278080  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.5      |
# |    n_updates        | 569494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18988    |
# |    fps              | 512      |
# |    time_elapsed     | 4447     |
# |    total_timesteps  | 2278560  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.48     |
# |    n_updates        | 569614   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18992    |
# |    fps              | 512      |
# |    time_elapsed     | 4448     |
# |    total_timesteps  | 2279040  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.6      |
# |    n_updates        | 569734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 18996    |
# |    fps              | 512      |
# |    time_elapsed     | 4449     |
# |    total_timesteps  | 2279520  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.09     |
# |    n_updates        | 569854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19000    |
# |    fps              | 512      |
# |    time_elapsed     | 4451     |
# |    total_timesteps  | 2280000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.17     |
# |    n_updates        | 569974   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19004    |
# |    fps              | 512      |
# |    time_elapsed     | 4452     |
# |    total_timesteps  | 2280480  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.71     |
# |    n_updates        | 570094   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19008    |
# |    fps              | 512      |
# |    time_elapsed     | 4453     |
# |    total_timesteps  | 2280960  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.36     |
# |    n_updates        | 570214   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19012    |
# |    fps              | 512      |
# |    time_elapsed     | 4454     |
# |    total_timesteps  | 2281440  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.79     |
# |    n_updates        | 570334   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19016    |
# |    fps              | 511      |
# |    time_elapsed     | 4456     |
# |    total_timesteps  | 2281920  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.68     |
# |    n_updates        | 570454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19020    |
# |    fps              | 511      |
# |    time_elapsed     | 4458     |
# |    total_timesteps  | 2282400  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.44     |
# |    n_updates        | 570574   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19024    |
# |    fps              | 511      |
# |    time_elapsed     | 4459     |
# |    total_timesteps  | 2282880  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.15     |
# |    n_updates        | 570694   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19028    |
# |    fps              | 511      |
# |    time_elapsed     | 4460     |
# |    total_timesteps  | 2283360  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.08     |
# |    n_updates        | 570814   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19032    |
# |    fps              | 511      |
# |    time_elapsed     | 4461     |
# |    total_timesteps  | 2283840  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.16     |
# |    n_updates        | 570934   |
# ...
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 11.3     |
# |    n_updates        | 596374   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 117      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19884    |
# |    fps              | 503      |
# |    time_elapsed     | 4736     |
# |    total_timesteps  | 2386080  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.37     |
# |    n_updates        | 596494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 117      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19888    |
# |    fps              | 503      |
# |    time_elapsed     | 4737     |
# |    total_timesteps  | 2386560  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 15.4     |
# |    n_updates        | 596614   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 117      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19892    |
# |    fps              | 503      |
# |    time_elapsed     | 4738     |
# |    total_timesteps  | 2387040  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.74     |
# |    n_updates        | 596734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19896    |
# |    fps              | 503      |
# |    time_elapsed     | 4739     |
# |    total_timesteps  | 2387520  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 11.4     |
# |    n_updates        | 596854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19900    |
# |    fps              | 503      |
# |    time_elapsed     | 4741     |
# |    total_timesteps  | 2388000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.02     |
# |    n_updates        | 596974   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19904    |
# |    fps              | 503      |
# |    time_elapsed     | 4742     |
# |    total_timesteps  | 2388480  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.51     |
# |    n_updates        | 597094   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19908    |
# |    fps              | 503      |
# |    time_elapsed     | 4744     |
# |    total_timesteps  | 2388960  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.4      |
# |    n_updates        | 597214   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19912    |
# |    fps              | 503      |
# |    time_elapsed     | 4746     |
# |    total_timesteps  | 2389440  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.09     |
# |    n_updates        | 597334   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19916    |
# |    fps              | 503      |
# |    time_elapsed     | 4747     |
# |    total_timesteps  | 2389920  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.55     |
# |    n_updates        | 597454   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19920    |
# |    fps              | 503      |
# |    time_elapsed     | 4748     |
# |    total_timesteps  | 2390400  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.19     |
# |    n_updates        | 597574   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 115      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19924    |
# |    fps              | 503      |
# |    time_elapsed     | 4749     |
# |    total_timesteps  | 2390880  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.75     |
# |    n_updates        | 597694   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19928    |
# |    fps              | 503      |
# |    time_elapsed     | 4750     |
# |    total_timesteps  | 2391360  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.03     |
# |    n_updates        | 597814   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19932    |
# |    fps              | 503      |
# |    time_elapsed     | 4751     |
# |    total_timesteps  | 2391840  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9        |
# |    n_updates        | 597934   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19936    |
# |    fps              | 503      |
# |    time_elapsed     | 4753     |
# |    total_timesteps  | 2392320  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 14.6     |
# |    n_updates        | 598054   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19940    |
# |    fps              | 503      |
# |    time_elapsed     | 4754     |
# |    total_timesteps  | 2392800  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.1      |
# |    n_updates        | 598174   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19944    |
# |    fps              | 503      |
# |    time_elapsed     | 4755     |
# |    total_timesteps  | 2393280  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.26     |
# |    n_updates        | 598294   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19948    |
# |    fps              | 503      |
# |    time_elapsed     | 4756     |
# |    total_timesteps  | 2393760  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.27     |
# |    n_updates        | 598414   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 113      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19952    |
# |    fps              | 503      |
# |    time_elapsed     | 4758     |
# |    total_timesteps  | 2394240  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.18     |
# |    n_updates        | 598534   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 112      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19956    |
# |    fps              | 503      |
# |    time_elapsed     | 4760     |
# |    total_timesteps  | 2394720  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.02     |
# |    n_updates        | 598654   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 112      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19960    |
# |    fps              | 503      |
# |    time_elapsed     | 4761     |
# |    total_timesteps  | 2395200  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.31     |
# |    n_updates        | 598774   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19964    |
# |    fps              | 502      |
# |    time_elapsed     | 4762     |
# |    total_timesteps  | 2395680  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.83     |
# |    n_updates        | 598894   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19968    |
# |    fps              | 502      |
# |    time_elapsed     | 4763     |
# |    total_timesteps  | 2396160  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02     |
# |    n_updates        | 599014   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19972    |
# |    fps              | 502      |
# |    time_elapsed     | 4765     |
# |    total_timesteps  | 2396640  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.45     |
# |    n_updates        | 599134   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19976    |
# |    fps              | 502      |
# |    time_elapsed     | 4766     |
# |    total_timesteps  | 2397120  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.86     |
# |    n_updates        | 599254   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19980    |
# |    fps              | 502      |
# |    time_elapsed     | 4767     |
# |    total_timesteps  | 2397600  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.04     |
# |    n_updates        | 599374   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 108      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19984    |
# |    fps              | 502      |
# |    time_elapsed     | 4768     |
# |    total_timesteps  | 2398080  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.26     |
# |    n_updates        | 599494   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 108      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19988    |
# |    fps              | 502      |
# |    time_elapsed     | 4769     |
# |    total_timesteps  | 2398560  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.98     |
# |    n_updates        | 599614   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19992    |
# |    fps              | 502      |
# |    time_elapsed     | 4770     |
# |    total_timesteps  | 2399040  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.07     |
# |    n_updates        | 599734   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 108      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 19996    |
# |    fps              | 502      |
# |    time_elapsed     | 4772     |
# |    total_timesteps  | 2399520  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.13     |
# |    n_updates        | 599854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 108      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 20000    |
# |    fps              | 502      |
# |    time_elapsed     | 4774     |
# |    total_timesteps  | 2400000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.39     |
# |    n_updates        | 599974   |
# ----------------------------------
# Training complete. Model and reward plot saved.

# %%
# Load the trained DQN agent
model = DQN.load("dqn_reservoir_agent")

# Set up variables for predictions
predicted_storage = []
actual_storage = []
predicted_release = []
actual_release = []

# Initialize current storage
current_storage = dataset[0,0]
print(current_storage)

# Perform predictions
for i in range(len(dataset)):
    # Get the observation from the dataset (without scaling)
    observation = np.array([current_storage, dataset[i, 1], dataset[i, 2]])
    # Predict the action using the trained agent
    action, _ = model.predict(observation)

    # Map the action to the corresponding release value in acre-feet
    predicted_release_af = release_af[action]

    # Extract inflow and evaporation directly from the dataset (unscaled)
    inflow_af = dataset[i, 2]
    evaporation_af = dataset[i, 1]

    # Update the current storage using the predicted release, inflow, and evaporation
    current_storage += inflow_af - evaporation_af - predicted_release_af

    # Store results for analysis
    predicted_storage.append(current_storage)
    predicted_release.append(predicted_release_af)
    actual_storage.append(dataset[i, 0])  # Actual storage from the dataset
    actual_release.append(dataset[i, 3])  # Actual release from the dataset
    # print(f"Step {i}: Observation: {observation}, Predicted Release: {predicted_release_af}, Current Storage: {current_storage}")


# Save results to CSV files
predicted_vs_actual_storage = pd.DataFrame({
    "Predicted Storage (af)": predicted_storage,
    "Actual Storage (af)": actual_storage
})
predicted_vs_actual_release = pd.DataFrame({
    "Predicted Release (af)": predicted_release,
    "Actual Release (af)": actual_release
})

# Save the results to CSV files
predicted_vs_actual_storage.to_csv("predicted_vs_actual_storage_complete_data.csv", index=False)
predicted_vs_actual_release.to_csv("predicted_vs_actual_release_complete_data.csv", index=False)
pd.DataFrame(dataset).to_csv("complete_dataset.csv", index=False)

print("Prediction completed and saved to CSV files.")

# Plot Predicted vs Actual Storage
plt.figure(figsize=(12, 6))
plt.plot(actual_storage, label="Actual Storage (af)", color="blue")
plt.plot(predicted_storage, label="Predicted Storage (af)", color="orange")
plt.xlabel("Timestep")
plt.ylabel("Storage (af)")
plt.title("Predicted vs Actual Storage")
plt.legend()
plt.grid()
plt.show()

# Plot Predicted vs Actual Release
plt.figure(figsize=(12, 6))
plt.plot(actual_release, label="Actual Release (af)", color="blue")
plt.plot(predicted_release, label="Predicted Release (af)", color="orange")
plt.xlabel("Timestep")
plt.ylabel("Release (af)")
plt.title("Predicted vs Actual Release")
plt.legend()
plt.grid()
plt.show()
# Out:
# 506159.0
# Prediction completed and saved to CSV files.

# %% [markdown]
# # **TD3 agent with simple binary rewards for storage volume constraints with smaller time steps (threshold) each episode - Agent Based State Propagation**

# %%
# Import necessary libraries
import os
import numpy as np
import pandas as pd
import torch as th
import gymnasium
from gymnasium import Env
from gymnasium.spaces import Box
from stable_baselines3 import TD3
from stable_baselines3.common.noise import NormalActionNoise
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# Define storage and release limits
min_storage_af = 500000
max_storage_af = 1800000
initial_storage_af = 500000
target_storage_af = (min_storage_af + max_storage_af) / 2
min_release_af = 500 * 1.98211  # Minimum release in acre-feet
max_release_af = 4000 * 1.98211  # Maximum release in acre-feet

# Load and preprocess data
data = pd.read_csv('/content/Clipped_NAVAJORESERVOIR08-18-2024T16.48.23.csv')
storage = data['Storage (af)'].values
evaporation = data['Evaporation (af)'].values
inflow_cfs = data['Inflow** (cfs)'].values
release_cfs = data['Total Release (cfs)'].values
dataset = np.column_stack((storage, evaporation, inflow_cfs * 1.98211, release_cfs * 1.98211))

# Define the custom Reservoir environment
class ReservoirEnv(Env):
    def __init__(self, dataset, min_storage_af, max_storage_af, min_release_af, max_release_af, episode_length, td3_model):
        super(ReservoirEnv, self).__init__()
        self.data = dataset
        self.episode_length = episode_length
        self.min_storage_af = min_storage_af
        self.max_storage_af = max_storage_af
        self.min_release_af = min_release_af
        self.max_release_af = max_release_af
        self.td3_model = td3_model  # To compute Q-values
        self.current_step = 0
        self.episode_step_count = 0
        self.reward_history = []
        self.episode_reward = []
        self.storage_history = []
        self.mean_storage_history = []
        self.q_values = []  # To collect Q-values for each step
        self.cumulative_q_values = []  # To store cumulative Q-values per episode
        self.release_history=[]
        self.mean_release_history=[]


        # Define action space and observation space
        self.action_space = Box(low=-1, high=1, shape=(1,), dtype=np.float32)
        self.observation_space = Box(low=np.array([self.min_storage_af, np.min(self.data[:, 1]), np.min(self.data[:, 2])]),
                                     high=np.array([self.max_storage_af, np.max(self.data[:, 1]), np.max(self.data[:, 2])]),
                                     dtype=np.float32)

    def reset(self, seed=None):
        self.current_step = np.random.randint(0, len(self.data) - self.episode_length)
        self.episode_step_count = 0
        self.reward_history.clear()
        self.q_values.clear()  # Reset Q-value history
        self.storage_history.clear()
        self.release_history.clear()
        self.current_storage = self.data[self.current_step, 0]
        return self._get_observation(), {}

    def _get_observation(self):
        return np.array([self.current_storage, self.data[self.current_step, 1], self.data[self.current_step, 2]])

    def step(self, action):
        # normalized_release = (action[0] + 1) / 2  # Convert from [-1, 1] to [0, 1]
        normalized_release = np.clip((action[0] + 1) / 2, 0, 1)
        release_af_value = self.min_release_af + normalized_release * (self.max_release_af - self.min_release_af)

        inflow_af = self.data[self.current_step, 2]
        evaporation_af = self.data[self.current_step, 1]
        self.current_storage += inflow_af - evaporation_af - release_af_value

        if self.min_storage_af <= self.current_storage <= self.max_storage_af:
            reward = 1
        else:
            reward = -1

        # Compute Q-value
        obs_tensor = th.tensor(self._get_observation(), dtype=th.float32).unsqueeze(0).to(self.td3_model.device)
        action_tensor = th.tensor(action, dtype=th.float32).unsqueeze(0).to(self.td3_model.device)
        # with th.no_grad():
        #     q_value = self.td3_model.critic_target(obs_tensor, action_tensor)[0].mean().item()
        with th.no_grad():
          q_value = self.td3_model.critic(obs_tensor, action_tensor)[0].mean().item()
        self.q_values.append(q_value)

        self.reward_history.append(reward)
        self.storage_history.append(self.current_storage)
        self.current_step += 1
        self.episode_step_count += 1
        done = self.current_step >= len(self.data) or (self.episode_step_count % self.episode_length == 0)

        if done:
            cum_reward = sum(self.reward_history)
            self.episode_reward.append(cum_reward)
            self.mean_storage_history.append(np.mean(self.storage_history))
            self.cumulative_q_values.append(np.sum(self.q_values))  # Save cumulative Q-values
            self.release_history.append(release_af_value)
            self.mean_release_history.append(np.mean(self.release_history))

        observation = self._get_observation() if not done else np.zeros(3)
        return observation, reward, done, False, {}

# Set up environment
episode_length = 120
env = ReservoirEnv(dataset, min_storage_af, max_storage_af, min_release_af, max_release_af, episode_length, None)

# Initialize TD3 model
n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))
model = TD3(
    "MlpPolicy",
    env,
    action_noise=action_noise,
    verbose=1,
    learning_rate=3e-4,
    batch_size=32,
    train_freq=(4, "step"),
    buffer_size=100000,
    tau=0.005,
    gamma=0.99,
    policy_delay=2,
    target_policy_noise=0.2,
    target_noise_clip=0.5,
)
# model = TD3("MlpPolicy", env, action_noise=action_noise, verbose=1)
env.td3_model = model  # Pass the TD3 model to the environment

# Train the model
n_episodes = 10000
total_timesteps = n_episodes * episode_length
model.learn(total_timesteps=total_timesteps)

# Save model
model.save("td3_reservoir_agent")

# Save cumulative Q-values to CSV
pd.DataFrame(env.cumulative_q_values, columns=["Cumulative Q-Value"]).to_csv("cumulative_q_values_per_episode.csv", index=False)


# Save cumulative reward values to CSV
pd.DataFrame(env.episode_reward).to_csv("cumulative_reward_per_episode.csv", index=False)

# Plot cumulative Q-values per episode
plt.figure(figsize=(12, 6))
plt.plot(env.cumulative_q_values, label="Cumulative Q-Value per Episode", color="orange")
plt.xlabel("Episode")
plt.ylabel("Cumulative Q-Value")
plt.title("Cumulative Q-Value per Episode vs Episode Number")
plt.grid()
plt.legend()
plt.savefig("cumulative_q_values_per_episode.png")
plt.show()

# Plot cumulative rewards per episode
plt.figure(figsize=(12, 6))
plt.plot(env.episode_reward, label="Cumulative Reward per Episode", color="blue")
plt.xlabel("Episode")
plt.ylabel("Cumulative Reward")
plt.title("Cumulative Reward per Episode vs Episode Number")
plt.grid()
plt.legend()
plt.savefig("cumulative_rewards_per_episode.png")
plt.show()

# Plot mean storage per episode
plt.figure(figsize=(12, 6))
plt.plot(env.mean_storage_history, label="Mean Storage per Episode", color="blue")
plt.xlabel("Episode")
plt.ylabel("Mean Storage")
plt.title("Mean Storage per Episode vs Episode Number")
plt.grid()
plt.legend()
plt.savefig("mean_storage_per_episode.png")
plt.show()

# Plot mean release per episode
plt.figure(figsize=(12, 6))
plt.plot(env.mean_release_history, label="Mean Release per Episode", color="blue")
plt.xlabel("Episode")
plt.ylabel("Mean Release")
plt.title("Mean Release per Episode vs Episode Number")
plt.grid()
plt.legend()
plt.savefig("mean_release_per_episode.png")
plt.show()

print("Training complete. Model, Q values, release, and reward plots saved.")
# Out:
# /usr/local/lib/python3.11/dist-packages/gymnasium/spaces/box.py:235: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /usr/local/lib/python3.11/dist-packages/gymnasium/spaces/box.py:305: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# Streaming output truncated to the last 5000 lines.
# |    actor_loss      | -22.2    |
# |    critic_loss     | 0.961    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 260014   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 107      |
# | time/              |          |
# |    episodes        | 8672     |
# |    fps             | 167      |
# |    time_elapsed    | 6216     |
# |    total_timesteps | 1040640  |
# | train/             |          |
# |    actor_loss      | -22.3    |
# |    critic_loss     | 1.19     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 260134   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 8676     |
# |    fps             | 167      |
# |    time_elapsed    | 6218     |
# |    total_timesteps | 1041120  |
# | train/             |          |
# |    actor_loss      | -22.3    |
# |    critic_loss     | 0.964    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 260254   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 8680     |
# |    fps             | 167      |
# |    time_elapsed    | 6221     |
# |    total_timesteps | 1041600  |
# | train/             |          |
# |    actor_loss      | -22.3    |
# |    critic_loss     | 1.18     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 260374   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 8684     |
# |    fps             | 167      |
# |    time_elapsed    | 6225     |
# |    total_timesteps | 1042080  |
# | train/             |          |
# |    actor_loss      | -22.3    |
# |    critic_loss     | 0.947    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 260494   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    episodes        | 8688     |
# |    fps             | 167      |
# |    time_elapsed    | 6228     |
# |    total_timesteps | 1042560  |
# | train/             |          |
# |    actor_loss      | -22.4    |
# |    critic_loss     | 29.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 260614   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    episodes        | 8692     |
# |    fps             | 167      |
# |    time_elapsed    | 6231     |
# |    total_timesteps | 1043040  |
# | train/             |          |
# |    actor_loss      | -22.4    |
# |    critic_loss     | 1.18     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 260734   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 8696     |
# |    fps             | 167      |
# |    time_elapsed    | 6233     |
# |    total_timesteps | 1043520  |
# | train/             |          |
# |    actor_loss      | -22.4    |
# |    critic_loss     | 1.19     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 260854   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    episodes        | 8700     |
# |    fps             | 167      |
# |    time_elapsed    | 6237     |
# |    total_timesteps | 1044000  |
# | train/             |          |
# |    actor_loss      | -22.4    |
# |    critic_loss     | 0.956    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 260974   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 8704     |
# |    fps             | 167      |
# |    time_elapsed    | 6240     |
# |    total_timesteps | 1044480  |
# | train/             |          |
# |    actor_loss      | -22.5    |
# |    critic_loss     | 1.19     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 261094   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 8708     |
# |    fps             | 167      |
# |    time_elapsed    | 6243     |
# |    total_timesteps | 1044960  |
# | train/             |          |
# |    actor_loss      | -22.5    |
# |    critic_loss     | 1.11     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 261214   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 8712     |
# |    fps             | 167      |
# |    time_elapsed    | 6246     |
# |    total_timesteps | 1045440  |
# | train/             |          |
# |    actor_loss      | -22.5    |
# |    critic_loss     | 29.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 261334   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 8716     |
# |    fps             | 167      |
# |    time_elapsed    | 6248     |
# |    total_timesteps | 1045920  |
# | train/             |          |
# |    actor_loss      | -22.5    |
# |    critic_loss     | 1.11     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 261454   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 101      |
# | time/              |          |
# |    episodes        | 8720     |
# |    fps             | 167      |
# |    time_elapsed    | 6252     |
# |    total_timesteps | 1046400  |
# | train/             |          |
# |    actor_loss      | -22.6    |
# |    critic_loss     | 1.03     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 261574   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 99.8     |
# | time/              |          |
# |    episodes        | 8724     |
# |    fps             | 167      |
# |    time_elapsed    | 6255     |
# |    total_timesteps | 1046880  |
# | train/             |          |
# |    actor_loss      | -22.6    |
# |    critic_loss     | 1.03     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 261694   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 102      |
# | time/              |          |
# |    episodes        | 8728     |
# |    fps             | 167      |
# |    time_elapsed    | 6258     |
# |    total_timesteps | 1047360  |
# | train/             |          |
# |    actor_loss      | -22.6    |
# |    critic_loss     | 35.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 261814   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 102      |
# | time/              |          |
# |    episodes        | 8732     |
# |    fps             | 167      |
# |    time_elapsed    | 6260     |
# |    total_timesteps | 1047840  |
# | train/             |          |
# |    actor_loss      | -22.6    |
# |    critic_loss     | 1.19     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 261934   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 101      |
# | time/              |          |
# |    episodes        | 8736     |
# |    fps             | 167      |
# |    time_elapsed    | 6263     |
# |    total_timesteps | 1048320  |
# | train/             |          |
# |    actor_loss      | -22.7    |
# |    critic_loss     | 1.03     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 262054   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 8740     |
# |    fps             | 167      |
# |    time_elapsed    | 6267     |
# |    total_timesteps | 1048800  |
# | train/             |          |
# |    actor_loss      | -22.7    |
# |    critic_loss     | 1.03     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 262174   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 8744     |
# |    fps             | 167      |
# |    time_elapsed    | 6270     |
# |    total_timesteps | 1049280  |
# | train/             |          |
# |    actor_loss      | -22.7    |
# |    critic_loss     | 0.95     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 262294   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 102      |
# | time/              |          |
# |    episodes        | 8748     |
# |    fps             | 167      |
# |    time_elapsed    | 6272     |
# |    total_timesteps | 1049760  |
# | train/             |          |
# |    actor_loss      | -22.7    |
# |    critic_loss     | 30.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 262414   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 102      |
# | time/              |          |
# |    episodes        | 8752     |
# |    fps             | 167      |
# |    time_elapsed    | 6275     |
# |    total_timesteps | 1050240  |
# | train/             |          |
# |    actor_loss      | -22.8    |
# |    critic_loss     | 1.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 262534   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 102      |
# | time/              |          |
# |    episodes        | 8756     |
# |    fps             | 167      |
# |    time_elapsed    | 6279     |
# |    total_timesteps | 1050720  |
# | train/             |          |
# |    actor_loss      | -22.8    |
# |    critic_loss     | 1.11     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 262654   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 102      |
# | time/              |          |
# |    episodes        | 8760     |
# |    fps             | 167      |
# |    time_elapsed    | 6282     |
# |    total_timesteps | 1051200  |
# | train/             |          |
# |    actor_loss      | -22.8    |
# |    critic_loss     | 1.02     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 262774   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 8764     |
# |    fps             | 167      |
# |    time_elapsed    | 6285     |
# |    total_timesteps | 1051680  |
# | train/             |          |
# |    actor_loss      | -22.8    |
# |    critic_loss     | 1.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 262894   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 8768     |
# |    fps             | 167      |
# |    time_elapsed    | 6287     |
# |    total_timesteps | 1052160  |
# | train/             |          |
# |    actor_loss      | -22.9    |
# |    critic_loss     | 1.18     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 263014   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    episodes        | 8772     |
# |    fps             | 167      |
# |    time_elapsed    | 6290     |
# |    total_timesteps | 1052640  |
# | train/             |          |
# |    actor_loss      | -22.9    |
# |    critic_loss     | 60.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 263134   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    episodes        | 8776     |
# |    fps             | 167      |
# |    time_elapsed    | 6294     |
# |    total_timesteps | 1053120  |
# | train/             |          |
# |    actor_loss      | -22.9    |
# |    critic_loss     | 1.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 263254   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 8780     |
# |    fps             | 167      |
# |    time_elapsed    | 6297     |
# |    total_timesteps | 1053600  |
# | train/             |          |
# |    actor_loss      | -23      |
# |    critic_loss     | 1.02     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 263374   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 107      |
# | time/              |          |
# |    episodes        | 8784     |
# |    fps             | 167      |
# |    time_elapsed    | 6300     |
# |    total_timesteps | 1054080  |
# | train/             |          |
# |    actor_loss      | -23      |
# |    critic_loss     | 1.02     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 263494   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 8788     |
# |    fps             | 167      |
# |    time_elapsed    | 6302     |
# |    total_timesteps | 1054560  |
# | train/             |          |
# |    actor_loss      | -23      |
# |    critic_loss     | 31.2     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 263614   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 8792     |
# |    fps             | 167      |
# |    time_elapsed    | 6306     |
# |    total_timesteps | 1055040  |
# | train/             |          |
# |    actor_loss      | -23      |
# |    critic_loss     | 0.944    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 263734   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 8796     |
# |    fps             | 167      |
# |    time_elapsed    | 6309     |
# |    total_timesteps | 1055520  |
# | train/             |          |
# |    actor_loss      | -23      |
# |    critic_loss     | 1.02     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 263854   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    episodes        | 8800     |
# |    fps             | 167      |
# |    time_elapsed    | 6312     |
# |    total_timesteps | 1056000  |
# | train/             |          |
# |    actor_loss      | -23.1    |
# |    critic_loss     | 1.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 263974   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 8804     |
# |    fps             | 167      |
# |    time_elapsed    | 6314     |
# |    total_timesteps | 1056480  |
# | train/             |          |
# |    actor_loss      | -23.1    |
# |    critic_loss     | 31.6     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 264094   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 107      |
# | time/              |          |
# |    episodes        | 8808     |
# |    fps             | 167      |
# |    time_elapsed    | 6317     |
# |    total_timesteps | 1056960  |
# | train/             |          |
# |    actor_loss      | -23.1    |
# |    critic_loss     | 32.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 264214   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 8812     |
# |    fps             | 167      |
# |    time_elapsed    | 6321     |
# |    total_timesteps | 1057440  |
# | train/             |          |
# |    actor_loss      | -23.2    |
# |    critic_loss     | 1.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 264334   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 107      |
# | time/              |          |
# |    episodes        | 8816     |
# |    fps             | 167      |
# |    time_elapsed    | 6324     |
# |    total_timesteps | 1057920  |
# | train/             |          |
# |    actor_loss      | -23.2    |
# |    critic_loss     | 1.03     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 264454   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 110      |
# | time/              |          |
# |    episodes        | 8820     |
# |    fps             | 167      |
# |    time_elapsed    | 6327     |
# |    total_timesteps | 1058400  |
# | train/             |          |
# |    actor_loss      | -23.2    |
# |    critic_loss     | 37.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 264574   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 111      |
# | time/              |          |
# |    episodes        | 8824     |
# |    fps             | 167      |
# |    time_elapsed    | 6329     |
# |    total_timesteps | 1058880  |
# | train/             |          |
# |    actor_loss      | -23.2    |
# |    critic_loss     | 31.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 264694   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 8828     |
# |    fps             | 167      |
# |    time_elapsed    | 6333     |
# |    total_timesteps | 1059360  |
# | train/             |          |
# |    actor_loss      | -23.3    |
# |    critic_loss     | 31.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 264814   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 8832     |
# |    fps             | 167      |
# |    time_elapsed    | 6336     |
# |    total_timesteps | 1059840  |
# | train/             |          |
# |    actor_loss      | -23.3    |
# |    critic_loss     | 0.936    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 264934   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 8836     |
# |    fps             | 167      |
# |    time_elapsed    | 6339     |
# |    total_timesteps | 1060320  |
# | train/             |          |
# |    actor_loss      | -23.3    |
# |    critic_loss     | 1.25     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 265054   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 8840     |
# |    fps             | 167      |
# |    time_elapsed    | 6342     |
# |    total_timesteps | 1060800  |
# | train/             |          |
# |    actor_loss      | -23.3    |
# |    critic_loss     | 0.936    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 265174   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 110      |
# | time/              |          |
# |    episodes        | 8844     |
# |    fps             | 167      |
# |    time_elapsed    | 6344     |
# |    total_timesteps | 1061280  |
# | train/             |          |
# |    actor_loss      | -23.4    |
# |    critic_loss     | 32.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 265294   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 8848     |
# |    fps             | 167      |
# |    time_elapsed    | 6348     |
# |    total_timesteps | 1061760  |
# | train/             |          |
# |    actor_loss      | -23.4    |
# |    critic_loss     | 63.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 265414   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 8852     |
# |    fps             | 167      |
# |    time_elapsed    | 6351     |
# |    total_timesteps | 1062240  |
# | train/             |          |
# |    actor_loss      | -23.4    |
# |    critic_loss     | 1.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 265534   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 8856     |
# |    fps             | 167      |
# |    time_elapsed    | 6354     |
# |    total_timesteps | 1062720  |
# | train/             |          |
# |    actor_loss      | -23.4    |
# |    critic_loss     | 1.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 265654   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 8860     |
# |    fps             | 167      |
# |    time_elapsed    | 6356     |
# |    total_timesteps | 1063200  |
# | train/             |          |
# |    actor_loss      | -23.5    |
# |    critic_loss     | 0.93     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 265774   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 8864     |
# |    fps             | 167      |
# |    time_elapsed    | 6360     |
# |    total_timesteps | 1063680  |
# | train/             |          |
# |    actor_loss      | -23.5    |
# |    critic_loss     | 1.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 265894   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 8868     |
# |    fps             | 167      |
# |    time_elapsed    | 6363     |
# |    total_timesteps | 1064160  |
# | train/             |          |
# |    actor_loss      | -23.5    |
# |    critic_loss     | 32.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 266014   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 8872     |
# |    fps             | 167      |
# |    time_elapsed    | 6366     |
# |    total_timesteps | 1064640  |
# | train/             |          |
# |    actor_loss      | -23.5    |
# |    critic_loss     | 1.25     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 266134   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 8876     |
# |    fps             | 167      |
# |    time_elapsed    | 6369     |
# |    total_timesteps | 1065120  |
# | train/             |          |
# |    actor_loss      | -23.5    |
# |    critic_loss     | 1.18     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 266254   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 8880     |
# |    fps             | 167      |
# |    time_elapsed    | 6372     |
# |    total_timesteps | 1065600  |
# | train/             |          |
# |    actor_loss      | -23.6    |
# |    critic_loss     | 32.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 266374   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 8884     |
# |    fps             | 167      |
# |    time_elapsed    | 6376     |
# |    total_timesteps | 1066080  |
# | train/             |          |
# |    actor_loss      | -23.6    |
# |    critic_loss     | 1.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 266494   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    episodes        | 8888     |
# |    fps             | 167      |
# |    time_elapsed    | 6378     |
# |    total_timesteps | 1066560  |
# | train/             |          |
# |    actor_loss      | -23.6    |
# |    critic_loss     | 1.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 266614   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    episodes        | 8892     |
# |    fps             | 167      |
# |    time_elapsed    | 6381     |
# |    total_timesteps | 1067040  |
# | train/             |          |
# |    actor_loss      | -23.6    |
# |    critic_loss     | 65.3     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 266734   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 8896     |
# |    fps             | 167      |
# |    time_elapsed    | 6384     |
# |    total_timesteps | 1067520  |
# | train/             |          |
# |    actor_loss      | -23.7    |
# |    critic_loss     | 1.09     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 266854   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 8900     |
# |    fps             | 167      |
# |    time_elapsed    | 6387     |
# |    total_timesteps | 1068000  |
# | train/             |          |
# |    actor_loss      | -23.7    |
# |    critic_loss     | 1.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 266974   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 8904     |
# |    fps             | 167      |
# |    time_elapsed    | 6391     |
# |    total_timesteps | 1068480  |
# | train/             |          |
# |    actor_loss      | -23.7    |
# |    critic_loss     | 1.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 267094   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 8908     |
# |    fps             | 167      |
# |    time_elapsed    | 6393     |
# |    total_timesteps | 1068960  |
# | train/             |          |
# |    actor_loss      | -23.7    |
# |    critic_loss     | 1.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 267214   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 8912     |
# |    fps             | 167      |
# |    time_elapsed    | 6396     |
# |    total_timesteps | 1069440  |
# | train/             |          |
# |    actor_loss      | -23.8    |
# |    critic_loss     | 33.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 267334   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 8916     |
# |    fps             | 167      |
# |    time_elapsed    | 6399     |
# |    total_timesteps | 1069920  |
# | train/             |          |
# |    actor_loss      | -23.8    |
# |    critic_loss     | 1        |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 267454   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 8920     |
# |    fps             | 167      |
# |    time_elapsed    | 6403     |
# |    total_timesteps | 1070400  |
# | train/             |          |
# |    actor_loss      | -23.8    |
# |    critic_loss     | 1.16     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 267574   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 8924     |
# |    fps             | 167      |
# |    time_elapsed    | 6406     |
# |    total_timesteps | 1070880  |
# | train/             |          |
# |    actor_loss      | -23.8    |
# |    critic_loss     | 33.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 267694   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 8928     |
# |    fps             | 167      |
# |    time_elapsed    | 6408     |
# |    total_timesteps | 1071360  |
# | train/             |          |
# |    actor_loss      | -23.9    |
# |    critic_loss     | 33.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 267814   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 8932     |
# |    fps             | 167      |
# |    time_elapsed    | 6411     |
# |    total_timesteps | 1071840  |
# | train/             |          |
# |    actor_loss      | -23.9    |
# |    critic_loss     | 1.08     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 267934   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 8936     |
# |    fps             | 167      |
# |    time_elapsed    | 6414     |
# |    total_timesteps | 1072320  |
# | train/             |          |
# |    actor_loss      | -23.9    |
# |    critic_loss     | 1.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 268054   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 107      |
# | time/              |          |
# |    episodes        | 8940     |
# |    fps             | 167      |
# |    time_elapsed    | 6418     |
# |    total_timesteps | 1072800  |
# | train/             |          |
# |    actor_loss      | -23.9    |
# |    critic_loss     | 1.08     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 268174   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 107      |
# | time/              |          |
# |    episodes        | 8944     |
# |    fps             | 167      |
# |    time_elapsed    | 6421     |
# |    total_timesteps | 1073280  |
# | train/             |          |
# |    actor_loss      | -24      |
# |    critic_loss     | 34.1     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 268294   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 8948     |
# |    fps             | 167      |
# |    time_elapsed    | 6423     |
# |    total_timesteps | 1073760  |
# | train/             |          |
# |    actor_loss      | -24      |
# |    critic_loss     | 34       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 268414   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 8952     |
# |    fps             | 167      |
# |    time_elapsed    | 6426     |
# |    total_timesteps | 1074240  |
# | train/             |          |
# |    actor_loss      | -24      |
# |    critic_loss     | 1.33     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 268534   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 8956     |
# |    fps             | 167      |
# |    time_elapsed    | 6430     |
# |    total_timesteps | 1074720  |
# | train/             |          |
# |    actor_loss      | -24      |
# |    critic_loss     | 1.09     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 268654   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 8960     |
# |    fps             | 167      |
# |    time_elapsed    | 6433     |
# |    total_timesteps | 1075200  |
# | train/             |          |
# |    actor_loss      | -24.1    |
# |    critic_loss     | 1.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 268774   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 8964     |
# |    fps             | 167      |
# |    time_elapsed    | 6435     |
# |    total_timesteps | 1075680  |
# | train/             |          |
# |    actor_loss      | -24.1    |
# |    critic_loss     | 1.09     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 268894   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 8968     |
# |    fps             | 167      |
# |    time_elapsed    | 6438     |
# |    total_timesteps | 1076160  |
# | train/             |          |
# |    actor_loss      | -24.1    |
# |    critic_loss     | 1.09     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 269014   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 8972     |
# |    fps             | 167      |
# |    time_elapsed    | 6441     |
# |    total_timesteps | 1076640  |
# | train/             |          |
# |    actor_loss      | -24.1    |
# |    critic_loss     | 0.931    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 269134   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 8976     |
# |    fps             | 167      |
# |    time_elapsed    | 6445     |
# |    total_timesteps | 1077120  |
# | train/             |          |
# |    actor_loss      | -24.2    |
# |    critic_loss     | 1.01     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 269254   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 8980     |
# |    fps             | 167      |
# |    time_elapsed    | 6448     |
# |    total_timesteps | 1077600  |
# | train/             |          |
# |    actor_loss      | -24.2    |
# |    critic_loss     | 34.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 269374   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 8984     |
# |    fps             | 167      |
# |    time_elapsed    | 6450     |
# |    total_timesteps | 1078080  |
# | train/             |          |
# |    actor_loss      | -24.2    |
# |    critic_loss     | 1.16     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 269494   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    episodes        | 8988     |
# |    fps             | 167      |
# |    time_elapsed    | 6453     |
# |    total_timesteps | 1078560  |
# | train/             |          |
# |    actor_loss      | -24.2    |
# |    critic_loss     | 34.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 269614   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 8992     |
# |    fps             | 167      |
# |    time_elapsed    | 6457     |
# |    total_timesteps | 1079040  |
# | train/             |          |
# |    actor_loss      | -24.2    |
# |    critic_loss     | 34.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 269734   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 8996     |
# |    fps             | 167      |
# |    time_elapsed    | 6460     |
# |    total_timesteps | 1079520  |
# | train/             |          |
# |    actor_loss      | -24.3    |
# |    critic_loss     | 34.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 269854   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 107      |
# | time/              |          |
# |    episodes        | 9000     |
# |    fps             | 167      |
# |    time_elapsed    | 6463     |
# |    total_timesteps | 1080000  |
# | train/             |          |
# |    actor_loss      | -24.3    |
# |    critic_loss     | 1        |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 269974   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 107      |
# | time/              |          |
# |    episodes        | 9004     |
# |    fps             | 167      |
# |    time_elapsed    | 6466     |
# |    total_timesteps | 1080480  |
# | train/             |          |
# |    actor_loss      | -24.3    |
# |    critic_loss     | 0.998    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 270094   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 9008     |
# |    fps             | 167      |
# |    time_elapsed    | 6468     |
# |    total_timesteps | 1080960  |
# | train/             |          |
# |    actor_loss      | -24.3    |
# |    critic_loss     | 34.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 270214   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 104      |
# | time/              |          |
# |    episodes        | 9012     |
# |    fps             | 167      |
# |    time_elapsed    | 6472     |
# |    total_timesteps | 1081440  |
# | train/             |          |
# |    actor_loss      | -24.4    |
# |    critic_loss     | 1.15     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 270334   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 9016     |
# |    fps             | 167      |
# |    time_elapsed    | 6475     |
# |    total_timesteps | 1081920  |
# | train/             |          |
# |    actor_loss      | -24.4    |
# |    critic_loss     | 0.991    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 270454   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 9020     |
# |    fps             | 167      |
# |    time_elapsed    | 6478     |
# |    total_timesteps | 1082400  |
# | train/             |          |
# |    actor_loss      | -24.4    |
# |    critic_loss     | 0.991    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 270574   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 102      |
# | time/              |          |
# |    episodes        | 9024     |
# |    fps             | 167      |
# |    time_elapsed    | 6481     |
# |    total_timesteps | 1082880  |
# | train/             |          |
# |    actor_loss      | -24.4    |
# |    critic_loss     | 41.4     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 270694   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 102      |
# | time/              |          |
# |    episodes        | 9028     |
# |    fps             | 167      |
# |    time_elapsed    | 6484     |
# |    total_timesteps | 1083360  |
# | train/             |          |
# |    actor_loss      | -24.5    |
# |    critic_loss     | 35.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 270814   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 9032     |
# |    fps             | 167      |
# |    time_elapsed    | 6487     |
# |    total_timesteps | 1083840  |
# | train/             |          |
# |    actor_loss      | -24.5    |
# |    critic_loss     | 1.15     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 270934   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 9036     |
# |    fps             | 167      |
# |    time_elapsed    | 6490     |
# |    total_timesteps | 1084320  |
# | train/             |          |
# |    actor_loss      | -24.5    |
# |    critic_loss     | 0.905    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 271054   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 102      |
# | time/              |          |
# |    episodes        | 9040     |
# |    fps             | 167      |
# |    time_elapsed    | 6493     |
# |    total_timesteps | 1084800  |
# | train/             |          |
# |    actor_loss      | -24.5    |
# |    critic_loss     | 41.8     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 271174   |
# ...
# |    learning_rate   | 0.0003   |
# |    n_updates       | 296254   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    episodes        | 9880     |
# |    fps             | 166      |
# |    time_elapsed    | 7125     |
# |    total_timesteps | 1185600  |
# | train/             |          |
# |    actor_loss      | -28.9    |
# |    critic_loss     | 1.02     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 296374   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 107      |
# | time/              |          |
# |    episodes        | 9884     |
# |    fps             | 166      |
# |    time_elapsed    | 7129     |
# |    total_timesteps | 1186080  |
# | train/             |          |
# |    actor_loss      | -28.9    |
# |    critic_loss     | 1.03     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 296494   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 107      |
# | time/              |          |
# |    episodes        | 9888     |
# |    fps             | 166      |
# |    time_elapsed    | 7132     |
# |    total_timesteps | 1186560  |
# | train/             |          |
# |    actor_loss      | -29      |
# |    critic_loss     | 1.02     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 296614   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 107      |
# | time/              |          |
# |    episodes        | 9892     |
# |    fps             | 166      |
# |    time_elapsed    | 7135     |
# |    total_timesteps | 1187040  |
# | train/             |          |
# |    actor_loss      | -29      |
# |    critic_loss     | 1.11     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 296734   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 9896     |
# |    fps             | 166      |
# |    time_elapsed    | 7138     |
# |    total_timesteps | 1187520  |
# | train/             |          |
# |    actor_loss      | -29      |
# |    critic_loss     | 98.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 296854   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 111      |
# | time/              |          |
# |    episodes        | 9900     |
# |    fps             | 166      |
# |    time_elapsed    | 7141     |
# |    total_timesteps | 1188000  |
# | train/             |          |
# |    actor_loss      | -29      |
# |    critic_loss     | 1.04     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 296974   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 111      |
# | time/              |          |
# |    episodes        | 9904     |
# |    fps             | 166      |
# |    time_elapsed    | 7144     |
# |    total_timesteps | 1188480  |
# | train/             |          |
# |    actor_loss      | -29      |
# |    critic_loss     | 57.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 297094   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 114      |
# | time/              |          |
# |    episodes        | 9908     |
# |    fps             | 166      |
# |    time_elapsed    | 7147     |
# |    total_timesteps | 1188960  |
# | train/             |          |
# |    actor_loss      | -29      |
# |    critic_loss     | 0.938    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 297214   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 114      |
# | time/              |          |
# |    episodes        | 9912     |
# |    fps             | 166      |
# |    time_elapsed    | 7150     |
# |    total_timesteps | 1189440  |
# | train/             |          |
# |    actor_loss      | -29.1    |
# |    critic_loss     | 1.11     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 297334   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 115      |
# | time/              |          |
# |    episodes        | 9916     |
# |    fps             | 166      |
# |    time_elapsed    | 7153     |
# |    total_timesteps | 1189920  |
# | train/             |          |
# |    actor_loss      | -29.1    |
# |    critic_loss     | 107      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 297454   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 115      |
# | time/              |          |
# |    episodes        | 9920     |
# |    fps             | 166      |
# |    time_elapsed    | 7156     |
# |    total_timesteps | 1190400  |
# | train/             |          |
# |    actor_loss      | -29.1    |
# |    critic_loss     | 0.852    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 297574   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 115      |
# | time/              |          |
# |    episodes        | 9924     |
# |    fps             | 166      |
# |    time_elapsed    | 7159     |
# |    total_timesteps | 1190880  |
# | train/             |          |
# |    actor_loss      | -29.1    |
# |    critic_loss     | 1.12     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 297694   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 9928     |
# |    fps             | 166      |
# |    time_elapsed    | 7162     |
# |    total_timesteps | 1191360  |
# | train/             |          |
# |    actor_loss      | -29.1    |
# |    critic_loss     | 1.12     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 297814   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 9932     |
# |    fps             | 166      |
# |    time_elapsed    | 7165     |
# |    total_timesteps | 1191840  |
# | train/             |          |
# |    actor_loss      | -29.1    |
# |    critic_loss     | 0.944    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 297934   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 9936     |
# |    fps             | 166      |
# |    time_elapsed    | 7168     |
# |    total_timesteps | 1192320  |
# | train/             |          |
# |    actor_loss      | -29.2    |
# |    critic_loss     | 50.7     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 298054   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 9940     |
# |    fps             | 166      |
# |    time_elapsed    | 7171     |
# |    total_timesteps | 1192800  |
# | train/             |          |
# |    actor_loss      | -29.2    |
# |    critic_loss     | 50.5     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 298174   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 9944     |
# |    fps             | 166      |
# |    time_elapsed    | 7174     |
# |    total_timesteps | 1193280  |
# | train/             |          |
# |    actor_loss      | -29.2    |
# |    critic_loss     | 1.11     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 298294   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 9948     |
# |    fps             | 166      |
# |    time_elapsed    | 7177     |
# |    total_timesteps | 1193760  |
# | train/             |          |
# |    actor_loss      | -29.2    |
# |    critic_loss     | 1.03     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 298414   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 114      |
# | time/              |          |
# |    episodes        | 9952     |
# |    fps             | 166      |
# |    time_elapsed    | 7180     |
# |    total_timesteps | 1194240  |
# | train/             |          |
# |    actor_loss      | -29.2    |
# |    critic_loss     | 0.949    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 298534   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 114      |
# | time/              |          |
# |    episodes        | 9956     |
# |    fps             | 166      |
# |    time_elapsed    | 7183     |
# |    total_timesteps | 1194720  |
# | train/             |          |
# |    actor_loss      | -29.2    |
# |    critic_loss     | 1.12     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 298654   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 9960     |
# |    fps             | 166      |
# |    time_elapsed    | 7186     |
# |    total_timesteps | 1195200  |
# | train/             |          |
# |    actor_loss      | -29.3    |
# |    critic_loss     | 0.86     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 298774   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 9964     |
# |    fps             | 166      |
# |    time_elapsed    | 7189     |
# |    total_timesteps | 1195680  |
# | train/             |          |
# |    actor_loss      | -29.3    |
# |    critic_loss     | 0.941    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 298894   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 9968     |
# |    fps             | 166      |
# |    time_elapsed    | 7192     |
# |    total_timesteps | 1196160  |
# | train/             |          |
# |    actor_loss      | -29.3    |
# |    critic_loss     | 101      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 299014   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 112      |
# | time/              |          |
# |    episodes        | 9972     |
# |    fps             | 166      |
# |    time_elapsed    | 7195     |
# |    total_timesteps | 1196640  |
# | train/             |          |
# |    actor_loss      | -29.3    |
# |    critic_loss     | 50.9     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 299134   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 9976     |
# |    fps             | 166      |
# |    time_elapsed    | 7198     |
# |    total_timesteps | 1197120  |
# | train/             |          |
# |    actor_loss      | -29.3    |
# |    critic_loss     | 0.951    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 299254   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 114      |
# | time/              |          |
# |    episodes        | 9980     |
# |    fps             | 166      |
# |    time_elapsed    | 7201     |
# |    total_timesteps | 1197600  |
# | train/             |          |
# |    actor_loss      | -29.3    |
# |    critic_loss     | 1.12     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 299374   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 115      |
# | time/              |          |
# |    episodes        | 9984     |
# |    fps             | 166      |
# |    time_elapsed    | 7204     |
# |    total_timesteps | 1198080  |
# | train/             |          |
# |    actor_loss      | -29.3    |
# |    critic_loss     | 1.03     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 299494   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 115      |
# | time/              |          |
# |    episodes        | 9988     |
# |    fps             | 166      |
# |    time_elapsed    | 7207     |
# |    total_timesteps | 1198560  |
# | train/             |          |
# |    actor_loss      | -29.4    |
# |    critic_loss     | 1.02     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 299614   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 114      |
# | time/              |          |
# |    episodes        | 9992     |
# |    fps             | 166      |
# |    time_elapsed    | 7210     |
# |    total_timesteps | 1199040  |
# | train/             |          |
# |    actor_loss      | -29.4    |
# |    critic_loss     | 0.847    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 299734   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 115      |
# | time/              |          |
# |    episodes        | 9996     |
# |    fps             | 166      |
# |    time_elapsed    | 7213     |
# |    total_timesteps | 1199520  |
# | train/             |          |
# |    actor_loss      | -29.4    |
# |    critic_loss     | 0.93     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 299854   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 115      |
# | time/              |          |
# |    episodes        | 10000    |
# |    fps             | 166      |
# |    time_elapsed    | 7216     |
# |    total_timesteps | 1200000  |
# | train/             |          |
# |    actor_loss      | -29.4    |
# |    critic_loss     | 0.929    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 299974   |
# ---------------------------------
# Training complete. Model, Q values, release, and reward plots saved.

# %%
# Load the trained TD3 agent
model = TD3.load("td3_reservoir_agent")

# Set up variables for predictions
predicted_storage = []
actual_storage = []
predicted_release = []
actual_release = []

# Initialize current storage from a realistic range
current_storage = np.random.uniform(min_storage_af, max_storage_af)
print(f"Initial Storage: {current_storage} AF")

# Perform predictions
for i in range(len(dataset)):
    # Get the observation
    observation = np.array([current_storage, dataset[i, 1], dataset[i, 2]], dtype=np.float32)

    # Predict action (allow slight randomness)
    action, _ = model.predict(observation, deterministic=False)

    # Convert TD3 action output from [-1,1] to [0,1] range
    normalized_release = np.clip((action[0] + 1) / 2, 0, 1)

    # Map normalized action to release value in acre-feet
    predicted_release_af = min_release_af + normalized_release * (max_release_af - min_release_af)

    # Extract actual inflow and evaporation from dataset
    inflow_af = dataset[i, 2]
    evaporation_af = dataset[i, 1]

    # Update current storage using mass balance
    current_storage += inflow_af - evaporation_af - predicted_release_af

    # Store results
    predicted_storage.append(current_storage)
    predicted_release.append(predicted_release_af)
    actual_storage.append(dataset[i, 0])
    actual_release.append(dataset[i, 3])

    # Print debug info
    print(f"Step {i}: Action: {action[0]}, Predicted Release: {predicted_release_af}, Updated Storage: {current_storage}")

    # Reset episodically to avoid accumulation
    if i % episode_length == 0:
        current_storage = np.random.uniform(min_storage_af, max_storage_af)

# Save results
predicted_vs_actual_storage = pd.DataFrame({
    "Predicted Storage (af)": predicted_storage,
    "Actual Storage (af)": actual_storage
})
predicted_vs_actual_release = pd.DataFrame({
    "Predicted Release (af)": predicted_release,
    "Actual Release (af)": actual_release
})

predicted_vs_actual_storage.to_csv("predicted_vs_actual_storage_complete_data.csv", index=False)
predicted_vs_actual_release.to_csv("predicted_vs_actual_release_complete_data.csv", index=False)

Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 1904290.0171740884
# Step 20870: Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 1904177.9098340883
# Step 20871: Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 1904054.9098340883
# Step 20872: Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 1903814.9832340884
# Step 20873: Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 1903342.1676540885
# Step 20874: Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 1902959.5470240884
# Step 20875: Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 1902558.1052940884
# Step 20876: Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 1902024.8621940883
# Step 20877: Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 1901616.4920240883
# Step 20878: Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 1901501.4920240883
# Step 20879: Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 1900780.9663640882
# Step 20880: Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 1900074.3333640883
# Step 20881: Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 698843.0917538095
# Step 20882: Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 698743.0023038095
# Step 20883: Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 698641.9307438096
# Step 20884: Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 699903.5687538096
# Step 20885: Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 701417.9347338096
# Step 20886: Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 702396.1489038096
# Step 20887: Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 702539.9126538096
# Step 20888: Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 702948.2970338096
# Step 20889: Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 704214.9350438096
# Step 20890: Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 702913.7584938096
# Step 20891: Action: -1.0, Predicted Release: 991.0550000000001, Updated Storage: 702700.7603338097
# Prediction completed and saved.

# %%
# Import necessary libraries
import os
import numpy as np
import pandas as pd
import torch as th
import gymnasium
from gymnasium import Env
from gymnasium.spaces import Box
from stable_baselines3 import TD3
from stable_baselines3.common.noise import NormalActionNoise
import matplotlib.pyplot as plt

# Define storage and release limits
min_storage_af = 500000
max_storage_af = 1800000
initial_storage_af = 500000
target_storage_af = (min_storage_af + max_storage_af) / 2
min_release_af = 500 * 1.98211  # Minimum release in acre-feet
max_release_af = 4000 * 1.98211  # Maximum release in acre-feet

# Load and preprocess data
data = pd.read_csv('/content/Clipped_NAVAJORESERVOIR08-18-2024T16.48.23.csv')
storage = data['Storage (af)'].values
evaporation = data['Evaporation (af)'].values
inflow_cfs = data['Inflow** (cfs)'].values
release_cfs = data['Total Release (cfs)'].values
dataset = np.column_stack((storage, evaporation, inflow_cfs * 1.98211, release_cfs * 1.98211))

# Define the custom Reservoir environment
class ReservoirEnv(Env):
    def __init__(self, dataset, min_storage_af, max_storage_af, min_release_af, max_release_af, episode_length, td3_model):
        super(ReservoirEnv, self).__init__()
        self.data = dataset
        self.episode_length = episode_length
        self.min_storage_af = min_storage_af
        self.max_storage_af = max_storage_af
        self.min_release_af = min_release_af
        self.max_release_af = max_release_af
        self.td3_model = td3_model  # To compute Q-values
        self.current_step = 0
        self.episode_step_count = 0
        self.global_step = 0  # Track total steps
        self.reward_history = []
        self.episode_reward = []
        self.storage_history = []
        self.mean_storage_history = []
        self.q_values = []
        self.cumulative_q_values = []
        self.release_history = []
        self.mean_release_history = []

        # Define action space and observation space
        self.action_space = Box(low=-1, high=1, shape=(1,), dtype=np.float32)
        self.observation_space = Box(low=np.array([self.min_storage_af, np.min(self.data[:, 1]), np.min(self.data[:, 2])]),
                                     high=np.array([self.max_storage_af, np.max(self.data[:, 1]), np.max(self.data[:, 2])]),
                                     dtype=np.float32)

    def reset(self, seed=None):
        self.current_step = np.random.randint(0, len(self.data) - self.episode_length)
        self.episode_step_count = 0
        self.reward_history.clear()
        self.q_values.clear()
        self.storage_history.clear()
        self.release_history.clear()
        self.current_storage = self.data[self.current_step, 0]
        print(f"[RESET] Global Step: {self.global_step}, Initial Storage: {self.current_storage}")
        return self._get_observation(), {}

    def _get_observation(self):
        return np.array([self.current_storage, self.data[self.current_step, 1], self.data[self.current_step, 2]])

    def step(self, action):
        self.global_step += 1

        # Ensure action is within expected range
        if not (-1 <= action[0] <= 1):
            print(f"[WARNING] Global Step: {self.global_step}, Unexpected action value: {action[0]}")

        normalized_release = np.clip((action[0] + 1) / 2, 0, 1)
        release_af_value = self.min_release_af + normalized_release * (self.max_release_af - self.min_release_af)

        inflow_af = self.data[self.current_step, 2]
        evaporation_af = self.data[self.current_step, 1]
        self.current_storage += inflow_af - evaporation_af - release_af_value

        if self.min_storage_af <= self.current_storage <= self.max_storage_af:
            reward = 1
        else:
            reward = -1

        # Compute Q-value
        obs_tensor = th.tensor(self._get_observation(), dtype=th.float32).unsqueeze(0).to(self.td3_model.device)
        action_tensor = th.tensor(action, dtype=th.float32).unsqueeze(0).to(self.td3_model.device)
        with th.no_grad():
            q_value = self.td3_model.critic(obs_tensor, action_tensor)[0].mean().item()
        self.q_values.append(q_value)

        self.reward_history.append(reward)
        self.storage_history.append(self.current_storage)
        self.release_history.append(release_af_value)

        print(f"[STEP] Global Step: {self.global_step}, Storage: {self.current_storage}, Release: {release_af_value}, Reward: {reward}, Q-value: {q_value}")

        self.current_step += 1
        self.episode_step_count += 1
        done = self.current_step >= len(self.data) or (self.episode_step_count % self.episode_length == 0)

        if done:
            cum_reward = sum(self.reward_history)
            self.episode_reward.append(cum_reward)
            self.mean_storage_history.append(np.mean(self.storage_history))
            self.cumulative_q_values.append(np.sum(self.q_values))
            self.mean_release_history.append(np.mean(self.release_history))

        observation = self._get_observation() if not done else np.zeros(3)
        return observation, reward, done, False, {}

# Set up environment
episode_length = 120
env = ReservoirEnv(dataset, min_storage_af, max_storage_af, min_release_af, max_release_af, episode_length, None)

# Initialize TD3 model
n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))
model = TD3(
    "MlpPolicy",
    env,
    action_noise=action_noise,
    verbose=1,
    learning_rate=3e-4,
    batch_size=32,
    train_freq=(4, "step"),
    buffer_size=100000,
    tau=0.005,
    gamma=0.99,
    policy_delay=2,
    target_policy_noise=0.2,
    target_noise_clip=0.5,
)
env.td3_model = model

# Train the model
n_episodes = 10000
total_timesteps = n_episodes * episode_length
model.learn(total_timesteps=total_timesteps)

# Save model and results
model.save("td3_reservoir_agent")
pd.DataFrame(env.cumulative_q_values, columns=["Cumulative Q-Value"]).to_csv("cumulative_q_values_per_episode.csv", index=False)
pd.DataFrame(env.episode_reward).to_csv("cumulative_reward_per_episode.csv", index=False)

# Plot results
plt.figure(figsize=(12, 6))
plt.plot(env.cumulative_q_values, label="Cumulative Q-Value per Episode", color="orange")
plt.xlabel("Episode")
plt.ylabel("Cumulative Q-Value")
plt.title("Cumulative Q-Value per Episode")
plt.legend()
plt.savefig("cumulative_q_values_per_episode.png")
plt.show()

plt.figure(figsize=(12, 6))
plt.plot(env.episode_reward, label="Cumulative Reward per Episode", color="blue")
plt.xlabel("Episode")
plt.ylabel("Cumulative Reward")
plt.title("Cumulative Reward per Episode")
plt.legend()
plt.savefig("cumulative_rewards_per_episode.png")
plt.show()

# Plot mean storage per episode
plt.figure(figsize=(12, 6))
plt.plot(env.mean_storage_history, label="Mean Storage per Episode", color="blue")
plt.xlabel("Episode")
plt.ylabel("Mean Storage")
plt.title("Mean Storage per Episode vs Episode Number")
plt.grid()
plt.legend()
plt.savefig("mean_storage_per_episode.png")
plt.show()

# Plot mean release per episode
plt.figure(figsize=(12, 6))
plt.plot(env.mean_release_history, label="Mean Release per Episode", color="blue")
plt.xlabel("Episode")
plt.ylabel("Mean Release")
plt.title("Mean Release per Episode vs Episode Number")
plt.grid()
plt.legend()
plt.savefig("mean_release_per_episode.png")
plt.show()

print("Training complete. Model, Q values, release, and reward plots saved.")
# Out:
# /usr/local/lib/python3.11/dist-packages/gymnasium/spaces/box.py:235: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /usr/local/lib/python3.11/dist-packages/gymnasium/spaces/box.py:305: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# Streaming output truncated to the last 5000 lines.
# |    episodes        | 9960     |
# |    fps             | 128      |
# |    time_elapsed    | 9270     |
# |    total_timesteps | 1195200  |
# | train/             |          |
# |    actor_loss      | -28.9    |
# |    critic_loss     | 154      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 298774   |
# ---------------------------------
# [STEP] Global Step: 1195201, Storage: 1339524.30056, Release: 991.0550000000001, Reward: 1, Q-value: 28.928945541381836
# [STEP] Global Step: 1195202, Storage: 1346366.5782199998, Release: 991.0550000000001, Reward: 1, Q-value: 28.928945541381836
# [STEP] Global Step: 1195203, Storage: 1353084.9650599998, Release: 991.0550000000001, Reward: 1, Q-value: 28.928945541381836
# [STEP] Global Step: 1195204, Storage: 1359493.3174841504, Release: 1301.071525849402, Reward: 1, Q-value: 28.928945541381836
# [STEP] Global Step: 1195205, Storage: 1365902.242418304, Release: 1111.1985658462347, Reward: 1, Q-value: 28.92906379699707
# [STEP] Global Step: 1195206, Storage: 1372591.843938304, Release: 991.0550000000001, Reward: 1, Q-value: 28.92906379699707
# [STEP] Global Step: 1195207, Storage: 1378801.7748383041, Release: 991.0550000000001, Reward: 1, Q-value: 28.92906379699707
# [STEP] Global Step: 1195208, Storage: 1384033.5255083041, Release: 991.0550000000001, Reward: 1, Q-value: 28.92906379699707
# [STEP] Global Step: 1195209, Storage: 1389168.6476862547, Release: 1579.2288820494712, Reward: 1, Q-value: 28.929149627685547
# [STEP] Global Step: 1195210, Storage: 1393804.7474662547, Release: 991.0550000000001, Reward: 1, Q-value: 28.929149627685547
# [STEP] Global Step: 1195211, Storage: 1398280.7075646503, Release: 1547.59879160434, Reward: 1, Q-value: 28.929149627685547
# [STEP] Global Step: 1195212, Storage: 1402749.899523747, Release: 1027.1256709034742, Reward: 1, Q-value: 28.929149627685547
# [STEP] Global Step: 1195213, Storage: 1407259.6992244744, Release: 1245.1743392725289, Reward: 1, Q-value: 28.9292049407959
# [STEP] Global Step: 1195483, Storage: 1319417.2738022218, Release: 1048.346509819776, Reward: 1, Q-value: 28.941198348999023
# [STEP] Global Step: 1195484, Storage: 1324962.738927813, Release: 1447.2561044086517, Reward: 1, Q-value: 28.941198348999023
# [STEP] Global Step: 1195485, Storage: 1331335.041837813, Release: 991.0550000000001, Reward: 1, Q-value: 28.94144630432129
# [STEP] Global Step: 1195486, Storage: 1338656.1143279055, Release: 1001.6087699076534, Reward: 1, Q-value: 28.94144630432129
# [STEP] Global Step: 1195487, Storage: 1343837.5310680023, Release: 1077.888009903133, Reward: 1, Q-value: 28.94144630432129
# [STEP] Global Step: 1195488, Storage: 1349801.4835380022, Release: 991.0550000000001, Reward: 1, Q-value: 28.94144630432129
# [STEP] Global Step: 1195489, Storage: 1357552.0725834882, Release: 1116.1545745140315, Reward: 1, Q-value: 28.941652297973633
# [STEP] Global Step: 1195490, Storage: 1367397.6078252017, Release: 1046.906908286512, Reward: 1, Q-value: 28.941652297973633
# [STEP] Global Step: 1195491, Storage: 1377081.9449852018, Release: 991.0550000000001, Reward: 1, Q-value: 28.941652297973633
# [STEP] Global Step: 1195492, Storage: 1382863.4831694656, Release: 1135.7555257363617, Reward: 1, Q-value: 28.941652297973633
# [STEP] Global Step: 1195493, Storage: 1388719.0375611782, Release: 1184.61224828735, Reward: 1, Q-value: 28.941869735717773
# [STEP] Global Step: 1195494, Storage: 1392748.5283329047, Release: 1142.5282482735813, Reward: 1, Q-value: 28.941869735717773
# [STEP] Global Step: 1195495, Storage: 1395041.506698925, Release: 1059.4636739796401, Reward: 1, Q-value: 28.941869735717773
# [STEP] Global Step: 1195496, Storage: 1398055.990038925, Release: 991.0550000000001, Reward: 1, Q-value: 28.941869735717773
# [STEP] Global Step: 1195497, Storage: 1399741.6064407625, Release: 1186.1550181625785, Reward: 1, Q-value: 28.942045211791992
# [STEP] Global Step: 1195498, Storage: 1402044.5463362562, Release: 1024.7168245062232, Reward: 1, Q-value: 28.942045211791992
# [STEP] Global Step: 1195499, Storage: 1403279.0948962562, Release: 991.0550000000001, Reward: 1, Q-value: 28.942045211791992
# [STEP] Global Step: 1195500, Storage: 1403481.192805344, Release: 1504.192830912173, Reward: 1, Q-value: 28.942045211791992
# [STEP] Global Step: 1195501, Storage: 1405259.821615344, Release: 991.0550000000001, Reward: 1, Q-value: 28.942228317260742
# [STEP] Global Step: 1195502, Storage: 1406148.9202651992, Release: 1523.805360144824, Reward: 1, Q-value: 28.942228317260742
# [STEP] Global Step: 1195503, Storage: 1407544.2656477252, Release: 1176.1274274739624, Reward: 1, Q-value: 28.942228317260742
# [STEP] Global Step: 1195504, Storage: 1408865.0270477252, Release: 991.0550000000001, Reward: 1, Q-value: 28.942228317260742
# [STEP] Global Step: 1195505, Storage: 1409932.0783677252, Release: 991.0550000000001, Reward: 1, Q-value: 28.942420959472656
# [STEP] Global Step: 1195506, Storage: 1410873.5486182598, Release: 1001.6736894655228, Reward: 1, Q-value: 28.942420959472656
# [STEP] Global Step: 1199979, Storage: 809221.7437362385, Release: 1481.204277920127, Reward: 1, Q-value: 29.112531661987305
# [STEP] Global Step: 1199980, Storage: 808453.5240462384, Release: 991.0550000000001, Reward: 1, Q-value: 29.112531661987305
# [STEP] Global Step: 1199981, Storage: 807686.3043562383, Release: 991.0550000000001, Reward: 1, Q-value: 29.112699508666992
# [STEP] Global Step: 1199982, Storage: 806706.9468048796, Release: 1292.3878113587202, Reward: 1, Q-value: 29.112699508666992
# [STEP] Global Step: 1199983, Storage: 806087.9007888358, Release: 1196.6790160436929, Reward: 1, Q-value: 29.112699508666992
# [STEP] Global Step: 1199984, Storage: 805321.6632088359, Release: 991.0550000000001, Reward: 1, Q-value: 29.112699508666992
# [STEP] Global Step: 1199985, Storage: 804379.0178388358, Release: 991.0550000000001, Reward: 1, Q-value: 29.112882614135742
# [STEP] Global Step: 1199986, Storage: 803614.7623688359, Release: 991.0550000000001, Reward: 1, Q-value: 29.112882614135742
# [STEP] Global Step: 1199987, Storage: 803026.9146888359, Release: 991.0550000000001, Reward: 1, Q-value: 29.112882614135742
# [STEP] Global Step: 1199988, Storage: 802261.6592188359, Release: 991.0550000000001, Reward: 1, Q-value: 29.112882614135742
# [STEP] Global Step: 1199989, Storage: 801587.9997147176, Release: 1077.8489341183008, Reward: 1, Q-value: 29.113079071044922
# [STEP] Global Step: 1199990, Storage: 800992.1946580381, Release: 1112.974756679535, Reward: 1, Q-value: 29.113079071044922
# [STEP] Global Step: 1199991, Storage: 800328.026798038, Release: 991.0550000000001, Reward: 1, Q-value: 29.113079071044922
# [STEP] Global Step: 1199992, Storage: 799487.451148038, Release: 991.0550000000001, Reward: 1, Q-value: 29.113079071044922
# [STEP] Global Step: 1199993, Storage: 798260.5369909047, Release: 1553.8012971332669, Reward: 1, Q-value: 29.113239288330078
# [STEP] Global Step: 1199994, Storage: 797684.5640809047, Release: 991.0550000000001, Reward: 1, Q-value: 29.113239288330078
# [STEP] Global Step: 1199995, Storage: 797170.0365809047, Release: 991.0550000000001, Reward: 1, Q-value: 29.113239288330078
# [STEP] Global Step: 1199996, Storage: 796433.5127609047, Release: 991.0550000000001, Reward: 1, Q-value: 29.113239288330078
# [STEP] Global Step: 1199997, Storage: 795375.4701559519, Release: 1398.786624952853, Reward: 1, Q-value: 29.1134090423584
# [STEP] Global Step: 1199998, Storage: 795157.2591559519, Release: 991.0550000000001, Reward: 1, Q-value: 29.1134090423584
# [STEP] Global Step: 1199999, Storage: 794448.3011198486, Release: 1221.145626103282, Reward: 1, Q-value: 29.1134090423584
# [STEP] Global Step: 1200000, Storage: 793880.2387598486, Release: 991.0550000000001, Reward: 1, Q-value: 29.1134090423584
# [RESET] Global Step: 1200000, Initial Storage: 1260000.0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 102      |
# | time/              |          |
# |    episodes        | 10000    |
# |    fps             | 128      |
# |    time_elapsed    | 9310     |
# |    total_timesteps | 1200000  |
# | train/             |          |
# |    actor_loss      | -29.1    |
# |    critic_loss     | 1.11     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 299974   |
# ---------------------------------
# Training complete. Model, Q values, release, and reward plots saved.
